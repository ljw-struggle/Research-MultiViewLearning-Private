# %%
import numpy as np
import pandas as pd

# %%
print(np.load('./TFLinkDataset/ProcessedData/HomoSapiens/protein.bert.npy', allow_pickle=True).item()['HES4'].shape)
print(np.load('./TFLinkDataset/ProcessedData/HomoSapiens/protein.vector.npy', allow_pickle=True).item()['HES4'].shape)
print(np.load('./TFLinkDataset/ProcessedData/HomoSapiens/protein.onehot.npy', allow_pickle=True).item()['HES4'].shape)
# Out:
# (1000, 26)
# (1000, 100)
# (1000, 20)

# %%
print(np.load('./TFLinkDataset/ProcessedData/HomoSapiens/promoter.bert.npy', allow_pickle=True).item()['HES4'].shape)
print(np.load('./TFLinkDataset/ProcessedData/HomoSapiens/promoter.vector.npy', allow_pickle=True).item()['HES4'].shape)
print(np.load('./TFLinkDataset/ProcessedData/HomoSapiens/promoter.onehot.npy', allow_pickle=True).item()['HES4'].shape)
# Out:
# (1000, 69)
# (1000, 100)
# (1000, 4)
