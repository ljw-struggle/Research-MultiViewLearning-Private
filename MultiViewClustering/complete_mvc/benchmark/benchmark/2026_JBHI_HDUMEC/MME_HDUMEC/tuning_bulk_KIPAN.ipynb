# %%
import os, random, argparse, itertools, numpy as np, scipy.io as sio
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import Dataset
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale
from _utils import MMDataset, clustering_acc, overall_performance_report

class DUCMME(nn.Module):
    def __init__(self, embed_dim=200, num_samples=10000, num_views=3, feature_dims=[1000, 1000, 500], hidden_dims=[512, 512, 512], n_clusters=10, alpha=1.0):
        super(DUCMME, self).__init__()
        self.embed_dim = embed_dim; self.num_samples = num_samples; self.num_views = num_views; self.feature_dims = feature_dims; self.hidden_dims = hidden_dims; self.n_clusters = n_clusters; self.alpha = alpha
        # 1. Multi-view Feature Extraction by Fusion-Net
        self.fusion_net_encoder = nn.ModuleList([nn.Sequential(nn.Linear(feature_dims[i], hidden_dims[i]), nn.BatchNorm1d(hidden_dims[i]), nn.ReLU(),
                                                               nn.Linear(hidden_dims[i], embed_dim)) for i in range(num_views)]) # encode each view
        self.fusion_net_mha = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=10, batch_first=True) # batch_first=True: (batch_size, seq_len, hidden_dim)
        self.fusion_net_linear = nn.Linear(3*embed_dim, embed_dim) # linear projection of the fused encoded features
        # 2. Uncertainty-Aware Reconstruction by Reconstruction-Net and Uncertainty-Net
        self.reconstruct_net_list = nn.ModuleList([nn.Sequential(nn.Linear(self.embed_dim, hidden_dims[i]), nn.BatchNorm1d(hidden_dims[i]), nn.ReLU(), 
                                                                 nn.Linear(hidden_dims[i], feature_dims[i])) for i in range(num_views)]) # reconstruct each view
        self.uncertainty_net_list = nn.ModuleList([nn.Sequential(nn.Linear(self.embed_dim, hidden_dims[i]), nn.BatchNorm1d(hidden_dims[i]), nn.ReLU(), 
                                                                 nn.Linear(hidden_dims[i], feature_dims[i])) for i in range(num_views)]) # predict uncertainty for each view
        # 3. Deep Embedding Clustering by DEC
        self._cluster_centers = nn.Parameter(torch.Tensor(self.n_clusters, self.embed_dim))
        nn.init.xavier_uniform_(self._cluster_centers.data)
        
    def forward_embedding(self, x):
        encoded_output_list = [self.fusion_net_encoder[i](x[i]) for i in range(self.num_views)] # encode each view
        encoded_output_list = torch.stack(encoded_output_list, dim=1) # stack the encoded features from all views, (batch_size, num_views, embed_dim)
        encoded_output_list, _ = self.fusion_net_mha(encoded_output_list, encoded_output_list, encoded_output_list) # fuse the encoded features from all views by a multihead attention, (batch_size, num_views, embed_dim)
        encoded_output_list = encoded_output_list.contiguous().view(encoded_output_list.shape[0], -1) # flatten the encoded features, (batch_size, num_views*embed_dim)
        embedding = self.fusion_net_linear(encoded_output_list) # linear projection of the fused encoded features
        return embedding # get the embedding of the latent space H, (batch_size, embed_dim)

    def forward_uncertainty_aware_reconstruction(self, x):
        embedding = self.forward_embedding(x) # shape: [batch_size, embed_dim]
        reconstructions = [self.reconstruct_net_list[i](embedding) for i in range(self.num_views)] # reconstruct each view
        uncertainties = [self.uncertainty_net_list[i](embedding) for i in range(self.num_views)] # predict uncertainty for each view
        return reconstructions, uncertainties
        
    def forward_similarity_matrix_q(self, x): # calculate the similarity matrix q using t-distribution
        embedding = self.forward_embedding(x) # shape: [batch_size, embed_dim]
        q = 1.0 / (1.0 + torch.sum((embedding.unsqueeze(1) - self._cluster_centers) ** 2, dim=2) / self.alpha) # shape: [batch_size, n_clusters]
        q = q ** ((self.alpha + 1.0) / 2.0) # , shape: [batch_size, n_clusters]
        q = q / torch.sum(q, dim=1, keepdim=True) # Normalize q to sum to 1 across clusters, shape: [batch_size, n_clusters]
        return q, embedding # q can be regarded as the probability of the sample belonging to each cluster
    
    @property
    def cluster_centers(self):
        return self._cluster_centers.data.detach().cpu().numpy() # shape: (n_clusters, embed_dim)
    
    @cluster_centers.setter
    def cluster_centers(self, centers): # shape: (n_clusters, embed_dim)
        centers = torch.tensor(centers, dtype=torch.float32, device=self._cluster_centers.device)
        self._cluster_centers.data.copy_(centers) # copy the cluster centers to the model, set the cluster centers to the new cluster centers
        
    @staticmethod
    def target_distribution(q):
        weight = q ** 2 / torch.sum(q, dim=0) # shape: [batch_size, n_clusters]
        p = weight / torch.sum(weight, dim=1, keepdim=True) # Normalize p to sum to 1 across clusters, shape: [batch_size, n_clusters]
        return p.clone().detach()
    
    def reconstruction_loss(self, x):
        x_rec, _ = self.forward_uncertainty_aware_reconstruction(x) # reconstruct each view and predict uncertainty
        return sum([F.mse_loss(x_rec[v], x[v], reduction='mean') for v in range(self.num_views)]) # sum the losses from all views
    
    def uncertainty_aware_reconstruction_loss(self, x):
        x_rec, log_sigma_2 = self.forward_uncertainty_aware_reconstruction(x) # reconstruct each view and predict uncertainty
        # Clip log_sigma_2 to prevent numerical instability (exp(-log_sigma_2) overflow/underflow)
        # Clamp to reasonable range: -10 to 10, which corresponds to sigma^2 from exp(-10) to exp(10)
        # log_sigma_2 = [torch.clamp(log_sigma_2[v], min=-10.0, max=10.0) for v in range(self.num_views)] # shape: [num_views, batch_size, feature_dim] for numerically stable computation
        return sum([0.5 * torch.mean((x_rec[v] - x[v])**2 * torch.exp(-log_sigma_2[v]) + log_sigma_2[v]) for v in range(self.num_views)]) # uncertainty is equal to log_sigma_2
    
    def clustering_loss(self, x, p):
        q, _ = self.forward_similarity_matrix_q(x) # shape: [batch_size, n_clusters]
        return F.kl_div(q.log(), p, reduction='batchmean') # shape: ()

# %%
random.seed(0); np.random.seed(0); torch.manual_seed(0); torch.cuda.manual_seed_all(0) # Set random seed for reproducibility
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
dataset = MMDataset('./data/data_bulk_multiomics/KIPAN/', concat_data=False)
data = [x.clone().to(device) for x in dataset.X]; label = dataset.Y.clone().numpy()
data_views = dataset.data_views; data_samples = dataset.data_samples; data_features = dataset.data_features; data_categories = dataset.categories
label_dict = dataset.get_label_to_name()

dataloader = torch.utils.data.DataLoader(dataset, batch_size=data_samples, shuffle=True)
model = DUCMME(embed_dim=20, feature_dims=data_features, num_views=data_views, hidden_dims=[512, 512, 512], num_samples=data_samples, n_clusters=data_categories, alpha=1.0).to(device)
## === Stage 1: Uncertainty-Aware Reconstruction Pretraining ===
print("\n=== Stage 1: Uncertainty-Aware Reconstruction Pretraining ===")
print("Basic reconstruction training...")
optimizer = torch.optim.Adam(model.parameters(), lr=5e-3)
losses_convergence_plot_reconstruction = []
for epoch in range(200):
    model.train()
    losses = []
    for batch_idx, (x, y, idx) in enumerate(dataloader):
        x = [x.to(device) for x in x]
        optimizer.zero_grad()
        loss = model.reconstruction_loss(x)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    losses_convergence_plot_reconstruction.append(np.mean(losses))
    print(f'Epoch {epoch} completed. Average Loss: {np.mean(losses):.4f}')
embedding = model.forward_embedding(data).detach().cpu().numpy() # shape: [num_samples, embed_dim]
kmeans = KMeans(n_clusters=data_categories, n_init=20, random_state=0)
preds = kmeans.fit_predict(embedding)
acc_val = clustering_acc(label, preds)
nmi_val = normalized_mutual_info_score(label, preds)
asw_val = silhouette_score(embedding, preds)
ari_val = adjusted_rand_score(label, preds)
print(f"Pretraining completed. ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}")
print("Uncertainty-aware reconstruction finetuning...")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
losses_convergence_plot_reconstruction_finetuning = []
for epoch in range(100):
    model.train()
    losses = []
    for batch_idx, (x, y, idx) in enumerate(dataloader):
        x = [x.to(device) for x in x]
        optimizer.zero_grad()
        loss = model.uncertainty_aware_reconstruction_loss(x)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    losses_convergence_plot_reconstruction_finetuning.append(np.mean(losses))
    print(f'Epoch {epoch} completed. Average Loss: {np.mean(losses):.4f}')
embedding = model.forward_embedding(data).detach().cpu().numpy() # shape: [num_samples, embed_dim]
kmeans = KMeans(n_clusters=data_categories, n_init=20, random_state=0)
preds = kmeans.fit_predict(embedding)
acc_val = clustering_acc(label, preds)
nmi_val = normalized_mutual_info_score(label, preds)
asw_val = silhouette_score(embedding, preds)
ari_val = adjusted_rand_score(label, preds)
print(f"Finetuning completed. ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}")

## === Stage 2: Deep Embedding Clustering by DEC ===
print("\n=== Stage 2: Deep Embedding Clustering ===")
print("Cluster center initialization...")
model.eval()
embedding = model.forward_embedding(data).detach().cpu().numpy() # shape: [num_samples, embed_dim]
kmeans = KMeans(n_clusters=data_categories, n_init=20, random_state=0)
preds = kmeans.fit_predict(embedding)
acc_val = clustering_acc(label, preds)
nmi_val = normalized_mutual_info_score(label, preds)
asw_val = silhouette_score(embedding, preds)
ari_val = adjusted_rand_score(label, preds)
print(f"Cluster center initialization completed. ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}")
model.cluster_centers = kmeans.cluster_centers_ # shape: (n_clusters, embed_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.9)
losses = []
acc_convergence_plot = []
nmi_convergence_plot = []
asw_convergence_plot = []
ari_convergence_plot = []
embeddings_dict = {}
preds_dict = {}
for epoch in range(150):
    # Update target distribution periodically
    if epoch % 1 == 0:
        model.eval()
        with torch.no_grad():
            q, embedding = model.forward_similarity_matrix_q(data)
            p = model.target_distribution(q)
        y_pred = torch.argmax(q, dim=1).cpu().numpy()
        acc_val = clustering_acc(label, y_pred)
        nmi_val = normalized_mutual_info_score(label, y_pred)
        if np.unique(y_pred).shape[0] > 1:
            asw_val = silhouette_score(embedding.cpu().numpy(), y_pred)
        else:
            asw_val = 0.0
        ari_val = adjusted_rand_score(label, y_pred)
        acc_convergence_plot.append(acc_val)
        nmi_convergence_plot.append(nmi_val)
        asw_convergence_plot.append(asw_val)
        ari_convergence_plot.append(ari_val)
        embeddings_dict[epoch] = embedding
        preds_dict[epoch] = y_pred
        if epoch == 0:
            delta_label = 1.0
            y_pred_last = y_pred.copy()
            print(f'[Epoch {epoch}] ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}, Delta: {delta_label:.4f}')
        else:
            delta_label = np.sum(y_pred != y_pred_last).astype(np.float32) / y_pred.shape[0]
            y_pred_last = y_pred.copy()
            print(f'[Epoch {epoch}] ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}, Delta: {delta_label:.4f}')
            if delta_label < 0.001:
                convergence_epoch = epoch
                print('Converged, stopping training...')
                # break
    # Training based on the target distribution that is updated periodically
    model.train()
    losses = []
    for batch_idx, (x, y, idx) in enumerate(dataloader):
        x = [x.to(device) for x in x]
        optimizer.zero_grad()
        loss = model.clustering_loss(x, p[idx])
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    scheduler.step()
    print(f'Epoch {epoch} completed. Average Loss: {np.mean(losses):.4f}')
print(f'Final ACC: {clustering_acc(label, y_pred):.4f}')
# Out:
# modality_mrna shape: (658, 2000)
# modality_meth shape: (658, 2000)
# modality_mirna shape: (658, 445)
#
# === Stage 1: Uncertainty-Aware Reconstruction Pretraining ===
# Basic reconstruction training...
# Epoch 0 completed. Average Loss: 1.4104
# Epoch 1 completed. Average Loss: 2.0111
# Epoch 2 completed. Average Loss: 0.9364
# Epoch 3 completed. Average Loss: 0.5025
# Epoch 4 completed. Average Loss: 0.5848
# Epoch 5 completed. Average Loss: 0.6181
# Epoch 6 completed. Average Loss: 0.4781
# Epoch 7 completed. Average Loss: 0.3206
# Epoch 8 completed. Average Loss: 0.2837
# Epoch 9 completed. Average Loss: 0.3130
# Epoch 10 completed. Average Loss: 0.3018
# Epoch 11 completed. Average Loss: 0.2489
# Epoch 12 completed. Average Loss: 0.2000
# Epoch 13 completed. Average Loss: 0.1801
# Epoch 14 completed. Average Loss: 0.1802
# Epoch 15 completed. Average Loss: 0.1729
# Epoch 16 completed. Average Loss: 0.1538
# Epoch 17 completed. Average Loss: 0.1333
# Epoch 18 completed. Average Loss: 0.1213
# Epoch 19 completed. Average Loss: 0.1200
# Epoch 20 completed. Average Loss: 0.1194
# Epoch 21 completed. Average Loss: 0.1107
# Epoch 22 completed. Average Loss: 0.0981
# Epoch 23 completed. Average Loss: 0.0886
# Epoch 24 completed. Average Loss: 0.0847
# Epoch 25 completed. Average Loss: 0.0842
# Epoch 26 completed. Average Loss: 0.0815
# Epoch 27 completed. Average Loss: 0.0756
# Epoch 28 completed. Average Loss: 0.0696
# Epoch 29 completed. Average Loss: 0.0660
# Epoch 30 completed. Average Loss: 0.0651
# Epoch 31 completed. Average Loss: 0.0646
# Epoch 32 completed. Average Loss: 0.0621
# Epoch 33 completed. Average Loss: 0.0588
# Epoch 34 completed. Average Loss: 0.0561
# Epoch 35 completed. Average Loss: 0.0544
# Epoch 36 completed. Average Loss: 0.0537
# Epoch 37 completed. Average Loss: 0.0526
# Epoch 38 completed. Average Loss: 0.0510
# Epoch 39 completed. Average Loss: 0.0495
# Epoch 40 completed. Average Loss: 0.0483
# Epoch 41 completed. Average Loss: 0.0475
# Epoch 42 completed. Average Loss: 0.0468
# Epoch 43 completed. Average Loss: 0.0459
# Epoch 44 completed. Average Loss: 0.0452
# Epoch 45 completed. Average Loss: 0.0444
# Epoch 46 completed. Average Loss: 0.0437
# Epoch 47 completed. Average Loss: 0.0432
# Epoch 48 completed. Average Loss: 0.0426
# Epoch 49 completed. Average Loss: 0.0421
# Epoch 50 completed. Average Loss: 0.0417
# Epoch 51 completed. Average Loss: 0.0413
# Epoch 52 completed. Average Loss: 0.0409
# Epoch 53 completed. Average Loss: 0.0405
# Epoch 54 completed. Average Loss: 0.0402
# Epoch 55 completed. Average Loss: 0.0398
# Epoch 56 completed. Average Loss: 0.0396
# Epoch 57 completed. Average Loss: 0.0393
# Epoch 58 completed. Average Loss: 0.0390
# Epoch 59 completed. Average Loss: 0.0388
# Epoch 60 completed. Average Loss: 0.0386
# Epoch 61 completed. Average Loss: 0.0384
# Epoch 62 completed. Average Loss: 0.0382
# Epoch 63 completed. Average Loss: 0.0380
# Epoch 64 completed. Average Loss: 0.0378
# Epoch 65 completed. Average Loss: 0.0376
# Epoch 66 completed. Average Loss: 0.0375
# Epoch 67 completed. Average Loss: 0.0373
# Epoch 68 completed. Average Loss: 0.0372
# Epoch 69 completed. Average Loss: 0.0370
# Epoch 70 completed. Average Loss: 0.0369
# Epoch 71 completed. Average Loss: 0.0367
# Epoch 72 completed. Average Loss: 0.0366
# Epoch 73 completed. Average Loss: 0.0365
# Epoch 74 completed. Average Loss: 0.0364
# Epoch 75 completed. Average Loss: 0.0363
# Epoch 76 completed. Average Loss: 0.0362
# Epoch 77 completed. Average Loss: 0.0361
# Epoch 78 completed. Average Loss: 0.0360
# Epoch 79 completed. Average Loss: 0.0359
# Epoch 80 completed. Average Loss: 0.0358
# Epoch 81 completed. Average Loss: 0.0357
# Epoch 82 completed. Average Loss: 0.0356
# Epoch 83 completed. Average Loss: 0.0355
# Epoch 84 completed. Average Loss: 0.0354
# Epoch 85 completed. Average Loss: 0.0353
# Epoch 86 completed. Average Loss: 0.0352
# Epoch 87 completed. Average Loss: 0.0351
# Epoch 88 completed. Average Loss: 0.0351
# Epoch 89 completed. Average Loss: 0.0350
# Epoch 90 completed. Average Loss: 0.0349
# Epoch 91 completed. Average Loss: 0.0348
# Epoch 92 completed. Average Loss: 0.0347
# Epoch 93 completed. Average Loss: 0.0347
# Epoch 94 completed. Average Loss: 0.0346
# Epoch 95 completed. Average Loss: 0.0345
# Epoch 96 completed. Average Loss: 0.0344
# Epoch 97 completed. Average Loss: 0.0344
# Epoch 98 completed. Average Loss: 0.0343
# Epoch 99 completed. Average Loss: 0.0342
# Epoch 100 completed. Average Loss: 0.0342
# Epoch 101 completed. Average Loss: 0.0341
# Epoch 102 completed. Average Loss: 0.0340
# Epoch 103 completed. Average Loss: 0.0339
# Epoch 104 completed. Average Loss: 0.0339
# Epoch 105 completed. Average Loss: 0.0338
# Epoch 106 completed. Average Loss: 0.0337
# Epoch 107 completed. Average Loss: 0.0337
# Epoch 108 completed. Average Loss: 0.0336
# Epoch 109 completed. Average Loss: 0.0336
# Epoch 110 completed. Average Loss: 0.0335
# Epoch 111 completed. Average Loss: 0.0334
# Epoch 112 completed. Average Loss: 0.0334
# Epoch 113 completed. Average Loss: 0.0333
# Epoch 114 completed. Average Loss: 0.0332
# Epoch 115 completed. Average Loss: 0.0332
# Epoch 116 completed. Average Loss: 0.0331
# Epoch 117 completed. Average Loss: 0.0331
# Epoch 118 completed. Average Loss: 0.0330
# Epoch 119 completed. Average Loss: 0.0329
# Epoch 120 completed. Average Loss: 0.0329
# Epoch 121 completed. Average Loss: 0.0328
# Epoch 122 completed. Average Loss: 0.0328
# Epoch 123 completed. Average Loss: 0.0327
# Epoch 124 completed. Average Loss: 0.0326
# Epoch 125 completed. Average Loss: 0.0326
# Epoch 126 completed. Average Loss: 0.0325
# Epoch 127 completed. Average Loss: 0.0325
# Epoch 128 completed. Average Loss: 0.0324
# Epoch 129 completed. Average Loss: 0.0324
# Epoch 130 completed. Average Loss: 0.0323
# Epoch 131 completed. Average Loss: 0.0322
# Epoch 132 completed. Average Loss: 0.0322
# Epoch 133 completed. Average Loss: 0.0321
# Epoch 134 completed. Average Loss: 0.0321
# Epoch 135 completed. Average Loss: 0.0320
# Epoch 136 completed. Average Loss: 0.0320
# Epoch 137 completed. Average Loss: 0.0319
# Epoch 138 completed. Average Loss: 0.0319
# Epoch 139 completed. Average Loss: 0.0318
# Epoch 140 completed. Average Loss: 0.0318
# Epoch 141 completed. Average Loss: 0.0317
# Epoch 142 completed. Average Loss: 0.0317
# Epoch 143 completed. Average Loss: 0.0316
# Epoch 144 completed. Average Loss: 0.0316
# Epoch 145 completed. Average Loss: 0.0315
# Epoch 146 completed. Average Loss: 0.0315
# Epoch 147 completed. Average Loss: 0.0314
# Epoch 148 completed. Average Loss: 0.0314
# Epoch 149 completed. Average Loss: 0.0313
# Epoch 150 completed. Average Loss: 0.0313
# Epoch 151 completed. Average Loss: 0.0312
# Epoch 152 completed. Average Loss: 0.0312
# Epoch 153 completed. Average Loss: 0.0311
# Epoch 154 completed. Average Loss: 0.0311
# Epoch 155 completed. Average Loss: 0.0311
# Epoch 156 completed. Average Loss: 0.0310
# Epoch 157 completed. Average Loss: 0.0310
# Epoch 158 completed. Average Loss: 0.0309
# Epoch 159 completed. Average Loss: 0.0309
# Epoch 160 completed. Average Loss: 0.0308
# Epoch 161 completed. Average Loss: 0.0308
# Epoch 162 completed. Average Loss: 0.0307
# Epoch 163 completed. Average Loss: 0.0307
# Epoch 164 completed. Average Loss: 0.0307
# Epoch 165 completed. Average Loss: 0.0306
# Epoch 166 completed. Average Loss: 0.0306
# Epoch 167 completed. Average Loss: 0.0305
# Epoch 168 completed. Average Loss: 0.0305
# Epoch 169 completed. Average Loss: 0.0305
# Epoch 170 completed. Average Loss: 0.0304
# Epoch 171 completed. Average Loss: 0.0304
# Epoch 172 completed. Average Loss: 0.0303
# Epoch 173 completed. Average Loss: 0.0303
# Epoch 174 completed. Average Loss: 0.0302
# Epoch 175 completed. Average Loss: 0.0302
# Epoch 176 completed. Average Loss: 0.0302
# Epoch 177 completed. Average Loss: 0.0301
# Epoch 178 completed. Average Loss: 0.0301
# Epoch 179 completed. Average Loss: 0.0300
# Epoch 180 completed. Average Loss: 0.0300
# Epoch 181 completed. Average Loss: 0.0300
# Epoch 182 completed. Average Loss: 0.0299
# Epoch 183 completed. Average Loss: 0.0299
# Epoch 184 completed. Average Loss: 0.0299
# Epoch 185 completed. Average Loss: 0.0298
# Epoch 186 completed. Average Loss: 0.0298
# Epoch 187 completed. Average Loss: 0.0297
# Epoch 188 completed. Average Loss: 0.0297
# Epoch 189 completed. Average Loss: 0.0297
# Epoch 190 completed. Average Loss: 0.0296
# Epoch 191 completed. Average Loss: 0.0296
# Epoch 192 completed. Average Loss: 0.0296
# Epoch 193 completed. Average Loss: 0.0295
# Epoch 194 completed. Average Loss: 0.0295
# Epoch 195 completed. Average Loss: 0.0295
# Epoch 196 completed. Average Loss: 0.0295
# Epoch 197 completed. Average Loss: 0.0295
# Epoch 198 completed. Average Loss: 0.0295
# Epoch 199 completed. Average Loss: 0.0295
# Pretraining completed. ACC: 0.8359, NMI: 0.5510, ASW: 0.6058, ARI: 0.5167
# Uncertainty-aware reconstruction finetuning...
# Epoch 0 completed. Average Loss: 0.0100
# Epoch 1 completed. Average Loss: -0.1464
# Epoch 2 completed. Average Loss: -0.5742
# Epoch 3 completed. Average Loss: -0.8184
# Epoch 4 completed. Average Loss: -1.1058
# Epoch 5 completed. Average Loss: -1.4974
# Epoch 6 completed. Average Loss: -1.8017
# Epoch 7 completed. Average Loss: -2.0784
# Epoch 8 completed. Average Loss: -2.4592
# Epoch 9 completed. Average Loss: -2.7534
# Epoch 10 completed. Average Loss: -3.0661
# Epoch 11 completed. Average Loss: -3.3717
# Epoch 12 completed. Average Loss: -3.6676
# Epoch 13 completed. Average Loss: -3.9341
# Epoch 14 completed. Average Loss: -4.2166
# Epoch 15 completed. Average Loss: -4.4382
# Epoch 16 completed. Average Loss: -4.6863
# Epoch 17 completed. Average Loss: -4.8751
# Epoch 18 completed. Average Loss: -5.0516
# Epoch 19 completed. Average Loss: -5.1875
# Epoch 20 completed. Average Loss: -5.2824
# Epoch 21 completed. Average Loss: -5.3613
# Epoch 22 completed. Average Loss: -5.3455
# Epoch 23 completed. Average Loss: -5.1943
# Epoch 24 completed. Average Loss: -5.2924
# Epoch 25 completed. Average Loss: -5.1962
# Epoch 26 completed. Average Loss: -5.4297
# Epoch 27 completed. Average Loss: -5.3695
# Epoch 28 completed. Average Loss: -5.5451
# Epoch 29 completed. Average Loss: -5.5390
# Epoch 30 completed. Average Loss: -5.6286
# Epoch 31 completed. Average Loss: -5.6750
# Epoch 32 completed. Average Loss: -5.6794
# Epoch 33 completed. Average Loss: -5.7387
# Epoch 34 completed. Average Loss: -5.7494
# Epoch 35 completed. Average Loss: -5.7534
# Epoch 36 completed. Average Loss: -5.7825
# Epoch 37 completed. Average Loss: -5.7941
# Epoch 38 completed. Average Loss: -5.8015
# Epoch 39 completed. Average Loss: -5.8230
# Epoch 40 completed. Average Loss: -5.8413
# Epoch 41 completed. Average Loss: -5.8565
# Epoch 42 completed. Average Loss: -5.8781
# Epoch 43 completed. Average Loss: -5.8977
# Epoch 44 completed. Average Loss: -5.9141
# Epoch 45 completed. Average Loss: -5.9332
# Epoch 46 completed. Average Loss: -5.9472
# Epoch 47 completed. Average Loss: -5.9613
# Epoch 48 completed. Average Loss: -5.9749
# Epoch 49 completed. Average Loss: -5.9842
# Epoch 50 completed. Average Loss: -5.9966
# Epoch 51 completed. Average Loss: -6.0065
# Epoch 52 completed. Average Loss: -6.0163
# Epoch 53 completed. Average Loss: -6.0264
# Epoch 54 completed. Average Loss: -6.0354
# Epoch 55 completed. Average Loss: -6.0447
# Epoch 56 completed. Average Loss: -6.0535
# Epoch 57 completed. Average Loss: -6.0623
# Epoch 58 completed. Average Loss: -6.0706
# Epoch 59 completed. Average Loss: -6.0784
# Epoch 60 completed. Average Loss: -6.0872
# Epoch 61 completed. Average Loss: -6.0943
# Epoch 62 completed. Average Loss: -6.1017
# Epoch 63 completed. Average Loss: -6.1084
# Epoch 64 completed. Average Loss: -6.1151
# Epoch 65 completed. Average Loss: -6.1214
# Epoch 66 completed. Average Loss: -6.1278
# Epoch 67 completed. Average Loss: -6.1331
# Epoch 68 completed. Average Loss: -6.1370
# Epoch 69 completed. Average Loss: -6.1372
# Epoch 70 completed. Average Loss: -6.1296
# Epoch 71 completed. Average Loss: -6.1118
# Epoch 72 completed. Average Loss: -6.1026
# Epoch 73 completed. Average Loss: -6.1292
# Epoch 74 completed. Average Loss: -6.1648
# Epoch 75 completed. Average Loss: -6.1655
# Epoch 76 completed. Average Loss: -6.1557
# Epoch 77 completed. Average Loss: -6.1724
# Epoch 78 completed. Average Loss: -6.1896
# Epoch 79 completed. Average Loss: -6.1862
# Epoch 80 completed. Average Loss: -6.1854
# Epoch 81 completed. Average Loss: -6.1989
# Epoch 82 completed. Average Loss: -6.2114
# Epoch 83 completed. Average Loss: -6.2164
# Epoch 84 completed. Average Loss: -6.2159
# Epoch 85 completed. Average Loss: -6.2163
# Epoch 86 completed. Average Loss: -6.2226
# Epoch 87 completed. Average Loss: -6.2306
# Epoch 88 completed. Average Loss: -6.2409
# Epoch 89 completed. Average Loss: -6.2504
# Epoch 90 completed. Average Loss: -6.2566
# Epoch 91 completed. Average Loss: -6.2606
# Epoch 92 completed. Average Loss: -6.2637
# Epoch 93 completed. Average Loss: -6.2625
# Epoch 94 completed. Average Loss: -6.2484
# Epoch 95 completed. Average Loss: -6.2088
# Epoch 96 completed. Average Loss: -6.1263
# Epoch 97 completed. Average Loss: -6.1395
# Epoch 98 completed. Average Loss: -6.1987
# Epoch 99 completed. Average Loss: -6.2080
# Finetuning completed. ACC: 0.8632, NMI: 0.5752, ASW: 0.5611, ARI: 0.6229
#
# === Stage 2: Deep Embedding Clustering ===
# Cluster center initialization...
# Cluster center initialization completed. ACC: 0.8632, NMI: 0.5742, ASW: 0.5660, ARI: 0.6243
# [Epoch 0] ACC: 0.8632, NMI: 0.5742, ASW: 0.5660, ARI: 0.6243, Delta: 1.0000
# Epoch 0 completed. Average Loss: 0.0700
# [Epoch 1] ACC: 0.8587, NMI: 0.5647, ASW: 0.6121, ARI: 0.6185, Delta: 0.0122
# Epoch 1 completed. Average Loss: 0.0640
# [Epoch 2] ACC: 0.8495, NMI: 0.5522, ASW: 0.6376, ARI: 0.6084, Delta: 0.0182
# Epoch 2 completed. Average Loss: 0.0598
# [Epoch 3] ACC: 0.8359, NMI: 0.5372, ASW: 0.6386, ARI: 0.5940, Delta: 0.0304
# Epoch 3 completed. Average Loss: 0.0619
# [Epoch 4] ACC: 0.8100, NMI: 0.5165, ASW: 0.6279, ARI: 0.5568, Delta: 0.0365
# Epoch 4 completed. Average Loss: 0.0713
# [Epoch 5] ACC: 0.7736, NMI: 0.4919, ASW: 0.6073, ARI: 0.4998, Delta: 0.0410
# Epoch 5 completed. Average Loss: 0.0882
# [Epoch 6] ACC: 0.7173, NMI: 0.4636, ASW: 0.5572, ARI: 0.4316, Delta: 0.0593
# Epoch 6 completed. Average Loss: 0.1219
# [Epoch 7] ACC: 0.6170, NMI: 0.4357, ASW: 0.4673, ARI: 0.3809, Delta: 0.1094
# Epoch 7 completed. Average Loss: 0.1878
# [Epoch 8] ACC: 0.7158, NMI: 0.4295, ASW: 0.4383, ARI: 0.4080, Delta: 0.1185
# Epoch 8 completed. Average Loss: 0.2350
# [Epoch 9] ACC: 0.7553, NMI: 0.4417, ASW: 0.4791, ARI: 0.4393, Delta: 0.0502
# Epoch 9 completed. Average Loss: 0.2150
# [Epoch 10] ACC: 0.7781, NMI: 0.4593, ASW: 0.5198, ARI: 0.4610, Delta: 0.0304
# Epoch 10 completed. Average Loss: 0.1565
# [Epoch 11] ACC: 0.7796, NMI: 0.4677, ASW: 0.5595, ARI: 0.4580, Delta: 0.0258
# Epoch 11 completed. Average Loss: 0.1157
# [Epoch 12] ACC: 0.7751, NMI: 0.4586, ASW: 0.5760, ARI: 0.4397, Delta: 0.0182
# Epoch 12 completed. Average Loss: 0.0955
# [Epoch 13] ACC: 0.7584, NMI: 0.4295, ASW: 0.5762, ARI: 0.3946, Delta: 0.0350
# Epoch 13 completed. Average Loss: 0.0892
# [Epoch 14] ACC: 0.7401, NMI: 0.4189, ASW: 0.5692, ARI: 0.3618, Delta: 0.0319
# Epoch 14 completed. Average Loss: 0.1027
# [Epoch 15] ACC: 0.6991, NMI: 0.3572, ASW: 0.5279, ARI: 0.2726, Delta: 0.0714
# Epoch 15 completed. Average Loss: 0.1219
# [Epoch 16] ACC: 0.6444, NMI: 0.2923, ASW: 0.4572, ARI: 0.1747, Delta: 0.0973
# Epoch 16 completed. Average Loss: 0.1625
# [Epoch 17] ACC: 0.5866, NMI: 0.2082, ASW: 0.3373, ARI: 0.0781, Delta: 0.1687
# Epoch 17 completed. Average Loss: 0.2255
# [Epoch 18] ACC: 0.5091, NMI: 0.0433, ASW: 0.1955, ARI: 0.0027, Delta: 0.1459
# Epoch 18 completed. Average Loss: 0.2477
# [Epoch 19] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0258
# Epoch 19 completed. Average Loss: 0.2419
# [Epoch 20] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 20 completed. Average Loss: 0.1953
# [Epoch 21] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 21 completed. Average Loss: 0.1352
# [Epoch 22] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 22 completed. Average Loss: 0.0935
# [Epoch 23] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 23 completed. Average Loss: 0.0748
# [Epoch 24] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 24 completed. Average Loss: 0.0651
# [Epoch 25] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 25 completed. Average Loss: 0.0562
# [Epoch 26] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 26 completed. Average Loss: 0.0472
# [Epoch 27] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 27 completed. Average Loss: 0.0389
# [Epoch 28] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 28 completed. Average Loss: 0.0318
# [Epoch 29] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 29 completed. Average Loss: 0.0260
# [Epoch 30] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 30 completed. Average Loss: 0.0213
# [Epoch 31] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 31 completed. Average Loss: 0.0176
# [Epoch 32] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 32 completed. Average Loss: 0.0146
# [Epoch 33] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 33 completed. Average Loss: 0.0121
# [Epoch 34] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 34 completed. Average Loss: 0.0101
# [Epoch 35] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 35 completed. Average Loss: 0.0086
# [Epoch 36] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 36 completed. Average Loss: 0.0073
# [Epoch 37] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 37 completed. Average Loss: 0.0062
# [Epoch 38] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 38 completed. Average Loss: 0.0054
# [Epoch 39] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 39 completed. Average Loss: 0.0046
# [Epoch 40] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 40 completed. Average Loss: 0.0040
# [Epoch 41] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 41 completed. Average Loss: 0.0035
# [Epoch 42] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 42 completed. Average Loss: 0.0031
# [Epoch 43] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 43 completed. Average Loss: 0.0028
# [Epoch 44] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 44 completed. Average Loss: 0.0025
# [Epoch 45] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 45 completed. Average Loss: 0.0023
# [Epoch 46] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 46 completed. Average Loss: 0.0021
# [Epoch 47] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 47 completed. Average Loss: 0.0019
# [Epoch 48] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 48 completed. Average Loss: 0.0018
# [Epoch 49] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 49 completed. Average Loss: 0.0017
# [Epoch 50] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 50 completed. Average Loss: 0.0016
# [Epoch 51] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 51 completed. Average Loss: 0.0015
# [Epoch 52] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 52 completed. Average Loss: 0.0015
# [Epoch 53] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 53 completed. Average Loss: 0.0014
# [Epoch 54] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 54 completed. Average Loss: 0.0014
# [Epoch 55] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 55 completed. Average Loss: 0.0013
# [Epoch 56] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 56 completed. Average Loss: 0.0013
# [Epoch 57] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 57 completed. Average Loss: 0.0013
# [Epoch 58] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 58 completed. Average Loss: 0.0013
# [Epoch 59] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 59 completed. Average Loss: 0.0013
# [Epoch 60] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 60 completed. Average Loss: 0.0013
# [Epoch 61] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 61 completed. Average Loss: 0.0013
# [Epoch 62] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 62 completed. Average Loss: 0.0013
# [Epoch 63] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 63 completed. Average Loss: 0.0013
# [Epoch 64] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 64 completed. Average Loss: 0.0013
# [Epoch 65] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 65 completed. Average Loss: 0.0013
# [Epoch 66] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 66 completed. Average Loss: 0.0013
# [Epoch 67] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 67 completed. Average Loss: 0.0013
# [Epoch 68] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 68 completed. Average Loss: 0.0014
# [Epoch 69] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 69 completed. Average Loss: 0.0014
# [Epoch 70] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 70 completed. Average Loss: 0.0014
# [Epoch 71] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 71 completed. Average Loss: 0.0014
# [Epoch 72] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 72 completed. Average Loss: 0.0014
# [Epoch 73] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 73 completed. Average Loss: 0.0014
# [Epoch 74] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 74 completed. Average Loss: 0.0015
# [Epoch 75] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 75 completed. Average Loss: 0.0015
# [Epoch 76] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 76 completed. Average Loss: 0.0015
# [Epoch 77] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 77 completed. Average Loss: 0.0015
# [Epoch 78] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 78 completed. Average Loss: 0.0016
# [Epoch 79] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 79 completed. Average Loss: 0.0016
# [Epoch 80] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 80 completed. Average Loss: 0.0016
# [Epoch 81] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 81 completed. Average Loss: 0.0016
# [Epoch 82] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 82 completed. Average Loss: 0.0017
# [Epoch 83] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 83 completed. Average Loss: 0.0017
# [Epoch 84] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 84 completed. Average Loss: 0.0017
# [Epoch 85] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 85 completed. Average Loss: 0.0017
# [Epoch 86] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 86 completed. Average Loss: 0.0018
# [Epoch 87] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 87 completed. Average Loss: 0.0018
# [Epoch 88] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 88 completed. Average Loss: 0.0018
# [Epoch 89] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 89 completed. Average Loss: 0.0019
# [Epoch 90] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 90 completed. Average Loss: 0.0019
# [Epoch 91] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 91 completed. Average Loss: 0.0019
# [Epoch 92] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 92 completed. Average Loss: 0.0020
# [Epoch 93] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 93 completed. Average Loss: 0.0020
# [Epoch 94] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 94 completed. Average Loss: 0.0020
# [Epoch 95] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 95 completed. Average Loss: 0.0021
# [Epoch 96] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 96 completed. Average Loss: 0.0021
# [Epoch 97] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 97 completed. Average Loss: 0.0021
# [Epoch 98] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 98 completed. Average Loss: 0.0022
# [Epoch 99] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 99 completed. Average Loss: 0.0022
# [Epoch 100] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 100 completed. Average Loss: 0.0023
# [Epoch 101] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 101 completed. Average Loss: 0.0023
# [Epoch 102] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 102 completed. Average Loss: 0.0024
# [Epoch 103] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 103 completed. Average Loss: 0.0024
# [Epoch 104] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 104 completed. Average Loss: 0.0025
# [Epoch 105] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 105 completed. Average Loss: 0.0026
# [Epoch 106] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 106 completed. Average Loss: 0.0026
# [Epoch 107] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 107 completed. Average Loss: 0.0027
# [Epoch 108] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 108 completed. Average Loss: 0.0028
# [Epoch 109] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 109 completed. Average Loss: 0.0028
# [Epoch 110] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 110 completed. Average Loss: 0.0029
# [Epoch 111] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 111 completed. Average Loss: 0.0030
# [Epoch 112] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 112 completed. Average Loss: 0.0030
# [Epoch 113] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 113 completed. Average Loss: 0.0031
# [Epoch 114] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 114 completed. Average Loss: 0.0032
# [Epoch 115] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 115 completed. Average Loss: 0.0033
# [Epoch 116] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 116 completed. Average Loss: 0.0034
# [Epoch 117] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 117 completed. Average Loss: 0.0034
# [Epoch 118] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 118 completed. Average Loss: 0.0035
# [Epoch 119] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 119 completed. Average Loss: 0.0036
# [Epoch 120] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 120 completed. Average Loss: 0.0037
# [Epoch 121] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 121 completed. Average Loss: 0.0038
# [Epoch 122] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 122 completed. Average Loss: 0.0039
# [Epoch 123] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 123 completed. Average Loss: 0.0041
# [Epoch 124] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 124 completed. Average Loss: 0.0042
# [Epoch 125] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 125 completed. Average Loss: 0.0043
# [Epoch 126] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 126 completed. Average Loss: 0.0044
# [Epoch 127] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 127 completed. Average Loss: 0.0045
# [Epoch 128] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 128 completed. Average Loss: 0.0046
# [Epoch 129] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 129 completed. Average Loss: 0.0048
# [Epoch 130] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 130 completed. Average Loss: 0.0049
# [Epoch 131] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 131 completed. Average Loss: 0.0050
# [Epoch 132] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 132 completed. Average Loss: 0.0052
# [Epoch 133] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 133 completed. Average Loss: 0.0053
# [Epoch 134] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 134 completed. Average Loss: 0.0055
# [Epoch 135] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 135 completed. Average Loss: 0.0056
# [Epoch 136] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 136 completed. Average Loss: 0.0058
# [Epoch 137] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 137 completed. Average Loss: 0.0061
# [Epoch 138] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 138 completed. Average Loss: 0.0063
# [Epoch 139] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 139 completed. Average Loss: 0.0066
# [Epoch 140] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 140 completed. Average Loss: 0.0069
# [Epoch 141] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 141 completed. Average Loss: 0.0074
# [Epoch 142] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 142 completed. Average Loss: 0.0078
# [Epoch 143] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 143 completed. Average Loss: 0.0084
# [Epoch 144] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 144 completed. Average Loss: 0.0089
# [Epoch 145] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 145 completed. Average Loss: 0.0095
# [Epoch 146] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 146 completed. Average Loss: 0.0101
# [Epoch 147] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 147 completed. Average Loss: 0.0108
# [Epoch 148] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 148 completed. Average Loss: 0.0114
# [Epoch 149] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 149 completed. Average Loss: 0.0121
# Final ACC: 0.4833

# %%
# modality_mrna shape: (658, 2000)
# modality_meth shape: (658, 2000)
# modality_mirna shape: (658, 445)
# === Stage 1: Uncertainty-Aware Reconstruction Pretraining ===
# Basic reconstruction training...
# Pretraining completed. ACC: 0.8359, NMI: 0.5510, ASW: 0.6058, ARI: 0.5167
# Uncertainty-aware reconstruction finetuning...
# Finetuning completed. ACC: 0.8632, NMI: 0.5752, ASW: 0.5611, ARI: 0.6229
# === Stage 2: Deep Embedding Clustering ===
# Cluster center initialization...
# Cluster center initialization completed. ACC: 0.8632, NMI: 0.5742, ASW: 0.5660, ARI: 0.6243
# [Epoch 0] ACC: 0.8632, NMI: 0.5742, ASW: 0.5660, ARI: 0.6243, Delta: 1.0000
# Epoch 0 completed. Average Loss: 0.0700
# [Epoch 1] ACC: 0.8587, NMI: 0.5647, ASW: 0.6121, ARI: 0.6185, Delta: 0.0122
# Epoch 1 completed. Average Loss: 0.0640
# [Epoch 2] ACC: 0.8495, NMI: 0.5522, ASW: 0.6376, ARI: 0.6084, Delta: 0.0182
# Epoch 2 completed. Average Loss: 0.0598
# [Epoch 3] ACC: 0.8359, NMI: 0.5372, ASW: 0.6386, ARI: 0.5940, Delta: 0.0304
# Epoch 3 completed. Average Loss: 0.0619
# [Epoch 4] ACC: 0.8100, NMI: 0.5165, ASW: 0.6279, ARI: 0.5568, Delta: 0.0365
# Epoch 4 completed. Average Loss: 0.0713
# [Epoch 5] ACC: 0.7736, NMI: 0.4919, ASW: 0.6073, ARI: 0.4998, Delta: 0.0410
# Epoch 5 completed. Average Loss: 0.0882
# [Epoch 6] ACC: 0.7173, NMI: 0.4636, ASW: 0.5572, ARI: 0.4316, Delta: 0.0593
# Epoch 6 completed. Average Loss: 0.1219
# [Epoch 7] ACC: 0.6170, NMI: 0.4357, ASW: 0.4673, ARI: 0.3809, Delta: 0.1094
# Epoch 7 completed. Average Loss: 0.1878
# [Epoch 8] ACC: 0.7158, NMI: 0.4295, ASW: 0.4383, ARI: 0.4080, Delta: 0.1185
# Epoch 8 completed. Average Loss: 0.2350
# [Epoch 9] ACC: 0.7553, NMI: 0.4417, ASW: 0.4791, ARI: 0.4393, Delta: 0.0502
# Epoch 9 completed. Average Loss: 0.2150
# [Epoch 10] ACC: 0.7781, NMI: 0.4593, ASW: 0.5198, ARI: 0.4610, Delta: 0.0304
# Epoch 10 completed. Average Loss: 0.1565
# [Epoch 11] ACC: 0.7796, NMI: 0.4677, ASW: 0.5595, ARI: 0.4580, Delta: 0.0258
# Epoch 11 completed. Average Loss: 0.1157
# [Epoch 12] ACC: 0.7751, NMI: 0.4586, ASW: 0.5760, ARI: 0.4397, Delta: 0.0182
# Epoch 12 completed. Average Loss: 0.0955
# [Epoch 13] ACC: 0.7584, NMI: 0.4295, ASW: 0.5762, ARI: 0.3946, Delta: 0.0350
# Epoch 13 completed. Average Loss: 0.0892
# [Epoch 14] ACC: 0.7401, NMI: 0.4189, ASW: 0.5692, ARI: 0.3618, Delta: 0.0319
# Epoch 14 completed. Average Loss: 0.1027
# [Epoch 15] ACC: 0.6991, NMI: 0.3572, ASW: 0.5279, ARI: 0.2726, Delta: 0.0714
# Epoch 15 completed. Average Loss: 0.1219
# [Epoch 16] ACC: 0.6444, NMI: 0.2923, ASW: 0.4572, ARI: 0.1747, Delta: 0.0973
# Epoch 16 completed. Average Loss: 0.1625
# [Epoch 17] ACC: 0.5866, NMI: 0.2082, ASW: 0.3373, ARI: 0.0781, Delta: 0.1687
# Epoch 17 completed. Average Loss: 0.2255
# [Epoch 18] ACC: 0.5091, NMI: 0.0433, ASW: 0.1955, ARI: 0.0027, Delta: 0.1459
# Epoch 18 completed. Average Loss: 0.2477
# [Epoch 19] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0258
# Epoch 19 completed. Average Loss: 0.2419
# [Epoch 20] ACC: 0.4833, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...

# %%
import numpy as np

epoch_data = {
    0: {'ACC': 0.8632, 'NMI': 0.5742, 'ASW': 0.5660, 'ARI': 0.6243},
    1: {'ACC': 0.8587, 'NMI': 0.5647, 'ASW': 0.6121, 'ARI': 0.6185},
    2: {'ACC': 0.8495, 'NMI': 0.5522, 'ASW': 0.6376, 'ARI': 0.6084},
    3: {'ACC': 0.8359, 'NMI': 0.5372, 'ASW': 0.6386, 'ARI': 0.5940},
    4: {'ACC': 0.8100, 'NMI': 0.5165, 'ASW': 0.6279, 'ARI': 0.5568}
}

metrics = ['ACC', 'NMI', 'ASW', 'ARI']
results = {}

for metric in metrics:
    values = [epoch_data[epoch][metric] for epoch in range(5)]
    mean_val = np.mean(values)
    var_val = np.var(values, ddof=0)  # 总体方差
    std_val = np.std(values, ddof=0)   # 总体标准差
    results[metric] = {
        'values': values,
        'mean': mean_val,
        'variance': var_val,
        'std': std_val
    }

print("=" * 60)
print("汇总表格:")
print("=" * 60)
print(f"{'指标':<8} {'均值':<12} {'方差':<12} {'标准差':<12}")
print("-" * 60)
for metric in metrics:
    print(f"{metric:<8} {results[metric]['mean']:<12.6f} {results[metric]['variance']:<12.6f} {results[metric]['std']:<12.6f}")
# Out:
# ============================================================
# 汇总表格:
# ============================================================
# 指标       均值           方差           标准差
# ------------------------------------------------------------
# ACC      0.843460     0.000367     0.019158
# NMI      0.548960     0.000417     0.020432
# ASW      0.616440     0.000727     0.026956
# ARI      0.600400     0.000581     0.024103
