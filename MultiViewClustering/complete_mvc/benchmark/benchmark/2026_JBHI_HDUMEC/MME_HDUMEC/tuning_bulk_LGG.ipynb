# %%
import os, random, argparse, itertools, numpy as np, scipy.io as sio
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import Dataset
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale
from _utils import MMDataset, clustering_acc, overall_performance_report

class DUCMME(nn.Module):
    def __init__(self, embed_dim=200, num_samples=10000, num_views=3, feature_dims=[1000, 1000, 500], hidden_dims=[512, 512, 512], n_clusters=10, alpha=1.0):
        super(DUCMME, self).__init__()
        self.embed_dim = embed_dim; self.num_samples = num_samples; self.num_views = num_views; self.feature_dims = feature_dims; self.hidden_dims = hidden_dims; self.n_clusters = n_clusters; self.alpha = alpha
        # 1. Multi-view Feature Extraction by Fusion-Net
        self.fusion_net_encoder = nn.ModuleList([nn.Sequential(nn.Linear(feature_dims[i], hidden_dims[i]), nn.BatchNorm1d(hidden_dims[i]), nn.ReLU(),
                                                               nn.Linear(hidden_dims[i], embed_dim)) for i in range(num_views)]) # encode each view
        self.fusion_net_mha = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=10, batch_first=True) # batch_first=True: (batch_size, seq_len, hidden_dim)
        self.fusion_net_linear = nn.Linear(3*embed_dim, embed_dim) # linear projection of the fused encoded features
        # 2. Uncertainty-Aware Reconstruction by Reconstruction-Net and Uncertainty-Net
        self.reconstruct_net_list = nn.ModuleList([nn.Sequential(nn.Linear(self.embed_dim, hidden_dims[i]), nn.BatchNorm1d(hidden_dims[i]), nn.ReLU(), 
                                                                 nn.Linear(hidden_dims[i], feature_dims[i])) for i in range(num_views)]) # reconstruct each view
        self.uncertainty_net_list = nn.ModuleList([nn.Sequential(nn.Linear(self.embed_dim, hidden_dims[i]), nn.BatchNorm1d(hidden_dims[i]), nn.ReLU(), 
                                                                 nn.Linear(hidden_dims[i], feature_dims[i])) for i in range(num_views)]) # predict uncertainty for each view
        # 3. Deep Embedding Clustering by DEC
        self._cluster_centers = nn.Parameter(torch.Tensor(self.n_clusters, self.embed_dim))
        nn.init.xavier_uniform_(self._cluster_centers.data)
        
    def forward_embedding(self, x):
        encoded_output_list = [self.fusion_net_encoder[i](x[i]) for i in range(self.num_views)] # encode each view
        encoded_output_list = torch.stack(encoded_output_list, dim=1) # stack the encoded features from all views, (batch_size, num_views, embed_dim)
        encoded_output_list, _ = self.fusion_net_mha(encoded_output_list, encoded_output_list, encoded_output_list) # fuse the encoded features from all views by a multihead attention, (batch_size, num_views, embed_dim)
        encoded_output_list = encoded_output_list.contiguous().view(encoded_output_list.shape[0], -1) # flatten the encoded features, (batch_size, num_views*embed_dim)
        embedding = self.fusion_net_linear(encoded_output_list) # linear projection of the fused encoded features
        return embedding # get the embedding of the latent space H, (batch_size, embed_dim)

    def forward_uncertainty_aware_reconstruction(self, x):
        embedding = self.forward_embedding(x) # shape: [batch_size, embed_dim]
        reconstructions = [self.reconstruct_net_list[i](embedding) for i in range(self.num_views)] # reconstruct each view
        uncertainties = [self.uncertainty_net_list[i](embedding) for i in range(self.num_views)] # predict uncertainty for each view
        return reconstructions, uncertainties
        
    def forward_similarity_matrix_q(self, x): # calculate the similarity matrix q using t-distribution
        embedding = self.forward_embedding(x) # shape: [batch_size, embed_dim]
        q = 1.0 / (1.0 + torch.sum((embedding.unsqueeze(1) - self._cluster_centers) ** 2, dim=2) / self.alpha) # shape: [batch_size, n_clusters]
        q = q ** ((self.alpha + 1.0) / 2.0) # , shape: [batch_size, n_clusters]
        q = q / torch.sum(q, dim=1, keepdim=True) # Normalize q to sum to 1 across clusters, shape: [batch_size, n_clusters]
        return q, embedding # q can be regarded as the probability of the sample belonging to each cluster
    
    @property
    def cluster_centers(self):
        return self._cluster_centers.data.detach().cpu().numpy() # shape: (n_clusters, embed_dim)
    
    @cluster_centers.setter
    def cluster_centers(self, centers): # shape: (n_clusters, embed_dim)
        centers = torch.tensor(centers, dtype=torch.float32, device=self._cluster_centers.device)
        self._cluster_centers.data.copy_(centers) # copy the cluster centers to the model, set the cluster centers to the new cluster centers
        
    @staticmethod
    def target_distribution(q):
        weight = q ** 2 / torch.sum(q, dim=0) # shape: [batch_size, n_clusters]
        p = weight / torch.sum(weight, dim=1, keepdim=True) # Normalize p to sum to 1 across clusters, shape: [batch_size, n_clusters]
        return p.clone().detach()
    
    def reconstruction_loss(self, x):
        x_rec, _ = self.forward_uncertainty_aware_reconstruction(x) # reconstruct each view and predict uncertainty
        return sum([F.mse_loss(x_rec[v], x[v], reduction='mean') for v in range(self.num_views)]) # sum the losses from all views
    
    def uncertainty_aware_reconstruction_loss(self, x):
        x_rec, log_sigma_2 = self.forward_uncertainty_aware_reconstruction(x) # reconstruct each view and predict uncertainty
        # Clip log_sigma_2 to prevent numerical instability (exp(-log_sigma_2) overflow/underflow)
        # Clamp to reasonable range: -10 to 10, which corresponds to sigma^2 from exp(-10) to exp(10)
        # log_sigma_2 = [torch.clamp(log_sigma_2[v], min=-10.0, max=10.0) for v in range(self.num_views)] # shape: [num_views, batch_size, feature_dim] for numerically stable computation
        return sum([0.5 * torch.mean((x_rec[v] - x[v])**2 * torch.exp(-log_sigma_2[v]) + log_sigma_2[v]) for v in range(self.num_views)]) # uncertainty is equal to log_sigma_2
    
    def clustering_loss(self, x, p):
        q, _ = self.forward_similarity_matrix_q(x) # shape: [batch_size, n_clusters]
        return F.kl_div(q.log(), p, reduction='batchmean') # shape: ()

# %%
random.seed(0); np.random.seed(0); torch.manual_seed(0); torch.cuda.manual_seed_all(0) # Set random seed for reproducibility
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
dataset = MMDataset('./data/data_bulk_multiomics/LGG/', concat_data=False)
data = [x.clone().to(device) for x in dataset.X]; label = dataset.Y.clone().numpy()
data_views = dataset.data_views; data_samples = dataset.data_samples; data_features = dataset.data_features; data_categories = dataset.categories
label_dict = dataset.get_label_to_name()

dataloader = torch.utils.data.DataLoader(dataset, batch_size=data_samples, shuffle=True)
model = DUCMME(embed_dim=20, feature_dims=data_features, num_views=data_views, hidden_dims=[512, 512, 512], num_samples=data_samples, n_clusters=data_categories, alpha=1.0).to(device)
## === Stage 1: Uncertainty-Aware Reconstruction Pretraining ===
print("\n=== Stage 1: Uncertainty-Aware Reconstruction Pretraining ===")
print("Basic reconstruction training...")
optimizer = torch.optim.Adam(model.parameters(), lr=5e-3)
losses_convergence_plot_reconstruction = []
for epoch in range(200):
    model.train()
    losses = []
    for batch_idx, (x, y, idx) in enumerate(dataloader):
        x = [x.to(device) for x in x]
        optimizer.zero_grad()
        loss = model.reconstruction_loss(x)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    losses_convergence_plot_reconstruction.append(np.mean(losses))
    print(f'Epoch {epoch} completed. Average Loss: {np.mean(losses):.4f}')
embedding = model.forward_embedding(data).detach().cpu().numpy() # shape: [num_samples, embed_dim]
kmeans = KMeans(n_clusters=data_categories, n_init=20, random_state=0)
preds = kmeans.fit_predict(embedding)
acc_val = clustering_acc(label, preds)
nmi_val = normalized_mutual_info_score(label, preds)
asw_val = silhouette_score(embedding, preds)
ari_val = adjusted_rand_score(label, preds)
print(f"Pretraining completed. ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}")
print("Uncertainty-aware reconstruction finetuning...")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
losses_convergence_plot_reconstruction_finetuning = []
for epoch in range(100):
    model.train()
    losses = []
    for batch_idx, (x, y, idx) in enumerate(dataloader):
        x = [x.to(device) for x in x]
        optimizer.zero_grad()
        loss = model.uncertainty_aware_reconstruction_loss(x)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    losses_convergence_plot_reconstruction_finetuning.append(np.mean(losses))
    print(f'Epoch {epoch} completed. Average Loss: {np.mean(losses):.4f}')
embedding = model.forward_embedding(data).detach().cpu().numpy() # shape: [num_samples, embed_dim]
kmeans = KMeans(n_clusters=data_categories, n_init=20, random_state=0)
preds = kmeans.fit_predict(embedding)
acc_val = clustering_acc(label, preds)
nmi_val = normalized_mutual_info_score(label, preds)
asw_val = silhouette_score(embedding, preds)
ari_val = adjusted_rand_score(label, preds)
print(f"Finetuning completed. ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}")

## === Stage 2: Deep Embedding Clustering by DEC ===
print("\n=== Stage 2: Deep Embedding Clustering ===")
print("Cluster center initialization...")
model.eval()
embedding = model.forward_embedding(data).detach().cpu().numpy() # shape: [num_samples, embed_dim]
kmeans = KMeans(n_clusters=data_categories, n_init=20, random_state=0)
preds = kmeans.fit_predict(embedding)
acc_val = clustering_acc(label, preds)
nmi_val = normalized_mutual_info_score(label, preds)
asw_val = silhouette_score(embedding, preds)
ari_val = adjusted_rand_score(label, preds)
print(f"Cluster center initialization completed. ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}")
model.cluster_centers = kmeans.cluster_centers_ # shape: (n_clusters, embed_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.9)
losses = []
acc_convergence_plot = []
nmi_convergence_plot = []
asw_convergence_plot = []
ari_convergence_plot = []
embeddings_dict = {}
preds_dict = {}
for epoch in range(150):
    # Update target distribution periodically
    if epoch % 1 == 0:
        model.eval()
        with torch.no_grad():
            q, embedding = model.forward_similarity_matrix_q(data)
            p = model.target_distribution(q)
        y_pred = torch.argmax(q, dim=1).cpu().numpy()
        acc_val = clustering_acc(label, y_pred)
        nmi_val = normalized_mutual_info_score(label, y_pred)
        if np.unique(y_pred).shape[0] > 1:
            asw_val = silhouette_score(embedding.cpu().numpy(), y_pred)
        else:
            asw_val = 0.0
        ari_val = adjusted_rand_score(label, y_pred)
        acc_convergence_plot.append(acc_val)
        nmi_convergence_plot.append(nmi_val)
        asw_convergence_plot.append(asw_val)
        ari_convergence_plot.append(ari_val)
        embeddings_dict[epoch] = embedding
        preds_dict[epoch] = y_pred
        if epoch == 0:
            delta_label = 1.0
            y_pred_last = y_pred.copy()
            print(f'[Epoch {epoch}] ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}, Delta: {delta_label:.4f}')
        else:
            delta_label = np.sum(y_pred != y_pred_last).astype(np.float32) / y_pred.shape[0]
            y_pred_last = y_pred.copy()
            print(f'[Epoch {epoch}] ACC: {acc_val:.4f}, NMI: {nmi_val:.4f}, ASW: {asw_val:.4f}, ARI: {ari_val:.4f}, Delta: {delta_label:.4f}')
            if delta_label < 0.001:
                convergence_epoch = epoch
                print('Converged, stopping training...')
                # break
    # Training based on the target distribution that is updated periodically
    model.train()
    losses = []
    for batch_idx, (x, y, idx) in enumerate(dataloader):
        x = [x.to(device) for x in x]
        optimizer.zero_grad()
        loss = model.clustering_loss(x, p[idx])
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    scheduler.step()
    print(f'Epoch {epoch} completed. Average Loss: {np.mean(losses):.4f}')
print(f'Final ACC: {clustering_acc(label, y_pred):.4f}')
# Out:
# modality_mrna shape: (510, 2000)
# modality_meth shape: (510, 2000)
# modality_mirna shape: (510, 548)
#
# === Stage 1: Uncertainty-Aware Reconstruction Pretraining ===
# Basic reconstruction training...
# Epoch 0 completed. Average Loss: 1.5005
# Epoch 1 completed. Average Loss: 1.6445
# Epoch 2 completed. Average Loss: 0.8204
# Epoch 3 completed. Average Loss: 0.5069
# Epoch 4 completed. Average Loss: 0.5917
# Epoch 5 completed. Average Loss: 0.5188
# Epoch 6 completed. Average Loss: 0.3628
# Epoch 7 completed. Average Loss: 0.2713
# Epoch 8 completed. Average Loss: 0.2717
# Epoch 9 completed. Average Loss: 0.2829
# Epoch 10 completed. Average Loss: 0.2392
# Epoch 11 completed. Average Loss: 0.1930
# Epoch 12 completed. Average Loss: 0.1633
# Epoch 13 completed. Average Loss: 0.1527
# Epoch 14 completed. Average Loss: 0.1538
# Epoch 15 completed. Average Loss: 0.1471
# Epoch 16 completed. Average Loss: 0.1283
# Epoch 17 completed. Average Loss: 0.1116
# Epoch 18 completed. Average Loss: 0.1023
# Epoch 19 completed. Average Loss: 0.0982
# Epoch 20 completed. Average Loss: 0.0978
# Epoch 21 completed. Average Loss: 0.0940
# Epoch 22 completed. Average Loss: 0.0853
# Epoch 23 completed. Average Loss: 0.0767
# Epoch 24 completed. Average Loss: 0.0717
# Epoch 25 completed. Average Loss: 0.0694
# Epoch 26 completed. Average Loss: 0.0689
# Epoch 27 completed. Average Loss: 0.0677
# Epoch 28 completed. Average Loss: 0.0638
# Epoch 29 completed. Average Loss: 0.0602
# Epoch 30 completed. Average Loss: 0.0573
# Epoch 31 completed. Average Loss: 0.0556
# Epoch 32 completed. Average Loss: 0.0552
# Epoch 33 completed. Average Loss: 0.0542
# Epoch 34 completed. Average Loss: 0.0525
# Epoch 35 completed. Average Loss: 0.0509
# Epoch 36 completed. Average Loss: 0.0493
# Epoch 37 completed. Average Loss: 0.0482
# Epoch 38 completed. Average Loss: 0.0477
# Epoch 39 completed. Average Loss: 0.0470
# Epoch 40 completed. Average Loss: 0.0463
# Epoch 41 completed. Average Loss: 0.0453
# Epoch 42 completed. Average Loss: 0.0445
# Epoch 43 completed. Average Loss: 0.0439
# Epoch 44 completed. Average Loss: 0.0435
# Epoch 45 completed. Average Loss: 0.0430
# Epoch 46 completed. Average Loss: 0.0425
# Epoch 47 completed. Average Loss: 0.0420
# Epoch 48 completed. Average Loss: 0.0416
# Epoch 49 completed. Average Loss: 0.0412
# Epoch 50 completed. Average Loss: 0.0409
# Epoch 51 completed. Average Loss: 0.0406
# Epoch 52 completed. Average Loss: 0.0402
# Epoch 53 completed. Average Loss: 0.0400
# Epoch 54 completed. Average Loss: 0.0397
# Epoch 55 completed. Average Loss: 0.0395
# Epoch 56 completed. Average Loss: 0.0393
# Epoch 57 completed. Average Loss: 0.0390
# Epoch 58 completed. Average Loss: 0.0388
# Epoch 59 completed. Average Loss: 0.0386
# Epoch 60 completed. Average Loss: 0.0385
# Epoch 61 completed. Average Loss: 0.0383
# Epoch 62 completed. Average Loss: 0.0382
# Epoch 63 completed. Average Loss: 0.0380
# Epoch 64 completed. Average Loss: 0.0379
# Epoch 65 completed. Average Loss: 0.0377
# Epoch 66 completed. Average Loss: 0.0376
# Epoch 67 completed. Average Loss: 0.0375
# Epoch 68 completed. Average Loss: 0.0374
# Epoch 69 completed. Average Loss: 0.0373
# Epoch 70 completed. Average Loss: 0.0372
# Epoch 71 completed. Average Loss: 0.0370
# Epoch 72 completed. Average Loss: 0.0369
# Epoch 73 completed. Average Loss: 0.0369
# Epoch 74 completed. Average Loss: 0.0368
# Epoch 75 completed. Average Loss: 0.0367
# Epoch 76 completed. Average Loss: 0.0366
# Epoch 77 completed. Average Loss: 0.0365
# Epoch 78 completed. Average Loss: 0.0364
# Epoch 79 completed. Average Loss: 0.0363
# Epoch 80 completed. Average Loss: 0.0363
# Epoch 81 completed. Average Loss: 0.0362
# Epoch 82 completed. Average Loss: 0.0361
# Epoch 83 completed. Average Loss: 0.0360
# Epoch 84 completed. Average Loss: 0.0360
# Epoch 85 completed. Average Loss: 0.0359
# Epoch 86 completed. Average Loss: 0.0358
# Epoch 87 completed. Average Loss: 0.0358
# Epoch 88 completed. Average Loss: 0.0357
# Epoch 89 completed. Average Loss: 0.0356
# Epoch 90 completed. Average Loss: 0.0356
# Epoch 91 completed. Average Loss: 0.0355
# Epoch 92 completed. Average Loss: 0.0354
# Epoch 93 completed. Average Loss: 0.0354
# Epoch 94 completed. Average Loss: 0.0353
# Epoch 95 completed. Average Loss: 0.0352
# Epoch 96 completed. Average Loss: 0.0352
# Epoch 97 completed. Average Loss: 0.0351
# Epoch 98 completed. Average Loss: 0.0350
# Epoch 99 completed. Average Loss: 0.0350
# Epoch 100 completed. Average Loss: 0.0349
# Epoch 101 completed. Average Loss: 0.0349
# Epoch 102 completed. Average Loss: 0.0348
# Epoch 103 completed. Average Loss: 0.0347
# Epoch 104 completed. Average Loss: 0.0347
# Epoch 105 completed. Average Loss: 0.0346
# Epoch 106 completed. Average Loss: 0.0346
# Epoch 107 completed. Average Loss: 0.0345
# Epoch 108 completed. Average Loss: 0.0344
# Epoch 109 completed. Average Loss: 0.0344
# Epoch 110 completed. Average Loss: 0.0343
# Epoch 111 completed. Average Loss: 0.0343
# Epoch 112 completed. Average Loss: 0.0342
# Epoch 113 completed. Average Loss: 0.0341
# Epoch 114 completed. Average Loss: 0.0341
# Epoch 115 completed. Average Loss: 0.0340
# Epoch 116 completed. Average Loss: 0.0340
# Epoch 117 completed. Average Loss: 0.0339
# Epoch 118 completed. Average Loss: 0.0339
# Epoch 119 completed. Average Loss: 0.0338
# Epoch 120 completed. Average Loss: 0.0338
# Epoch 121 completed. Average Loss: 0.0337
# Epoch 122 completed. Average Loss: 0.0336
# Epoch 123 completed. Average Loss: 0.0336
# Epoch 124 completed. Average Loss: 0.0335
# Epoch 125 completed. Average Loss: 0.0335
# Epoch 126 completed. Average Loss: 0.0334
# Epoch 127 completed. Average Loss: 0.0334
# Epoch 128 completed. Average Loss: 0.0333
# Epoch 129 completed. Average Loss: 0.0333
# Epoch 130 completed. Average Loss: 0.0332
# Epoch 131 completed. Average Loss: 0.0332
# Epoch 132 completed. Average Loss: 0.0331
# Epoch 133 completed. Average Loss: 0.0331
# Epoch 134 completed. Average Loss: 0.0330
# Epoch 135 completed. Average Loss: 0.0330
# Epoch 136 completed. Average Loss: 0.0329
# Epoch 137 completed. Average Loss: 0.0329
# Epoch 138 completed. Average Loss: 0.0329
# Epoch 139 completed. Average Loss: 0.0329
# Epoch 140 completed. Average Loss: 0.0330
# Epoch 141 completed. Average Loss: 0.0333
# Epoch 142 completed. Average Loss: 0.0338
# Epoch 143 completed. Average Loss: 0.0348
# Epoch 144 completed. Average Loss: 0.0351
# Epoch 145 completed. Average Loss: 0.0343
# Epoch 146 completed. Average Loss: 0.0327
# Epoch 147 completed. Average Loss: 0.0329
# Epoch 148 completed. Average Loss: 0.0337
# Epoch 149 completed. Average Loss: 0.0329
# Epoch 150 completed. Average Loss: 0.0324
# Epoch 151 completed. Average Loss: 0.0330
# Epoch 152 completed. Average Loss: 0.0327
# Epoch 153 completed. Average Loss: 0.0322
# Epoch 154 completed. Average Loss: 0.0326
# Epoch 155 completed. Average Loss: 0.0325
# Epoch 156 completed. Average Loss: 0.0320
# Epoch 157 completed. Average Loss: 0.0323
# Epoch 158 completed. Average Loss: 0.0323
# Epoch 159 completed. Average Loss: 0.0319
# Epoch 160 completed. Average Loss: 0.0320
# Epoch 161 completed. Average Loss: 0.0321
# Epoch 162 completed. Average Loss: 0.0318
# Epoch 163 completed. Average Loss: 0.0318
# Epoch 164 completed. Average Loss: 0.0319
# Epoch 165 completed. Average Loss: 0.0317
# Epoch 166 completed. Average Loss: 0.0316
# Epoch 167 completed. Average Loss: 0.0317
# Epoch 168 completed. Average Loss: 0.0315
# Epoch 169 completed. Average Loss: 0.0314
# Epoch 170 completed. Average Loss: 0.0314
# Epoch 171 completed. Average Loss: 0.0314
# Epoch 172 completed. Average Loss: 0.0313
# Epoch 173 completed. Average Loss: 0.0312
# Epoch 174 completed. Average Loss: 0.0313
# Epoch 175 completed. Average Loss: 0.0312
# Epoch 176 completed. Average Loss: 0.0311
# Epoch 177 completed. Average Loss: 0.0311
# Epoch 178 completed. Average Loss: 0.0310
# Epoch 179 completed. Average Loss: 0.0310
# Epoch 180 completed. Average Loss: 0.0309
# Epoch 181 completed. Average Loss: 0.0309
# Epoch 182 completed. Average Loss: 0.0308
# Epoch 183 completed. Average Loss: 0.0308
# Epoch 184 completed. Average Loss: 0.0307
# Epoch 185 completed. Average Loss: 0.0307
# Epoch 186 completed. Average Loss: 0.0306
# Epoch 187 completed. Average Loss: 0.0306
# Epoch 188 completed. Average Loss: 0.0305
# Epoch 189 completed. Average Loss: 0.0305
# Epoch 190 completed. Average Loss: 0.0304
# Epoch 191 completed. Average Loss: 0.0304
# Epoch 192 completed. Average Loss: 0.0303
# Epoch 193 completed. Average Loss: 0.0303
# Epoch 194 completed. Average Loss: 0.0302
# Epoch 195 completed. Average Loss: 0.0302
# Epoch 196 completed. Average Loss: 0.0302
# Epoch 197 completed. Average Loss: 0.0301
# Epoch 198 completed. Average Loss: 0.0301
# Epoch 199 completed. Average Loss: 0.0300
# Pretraining completed. ACC: 0.6176, NMI: 0.1486, ASW: 0.6199, ARI: 0.0538
# Uncertainty-aware reconstruction finetuning...
# Epoch 0 completed. Average Loss: 0.0113
# Epoch 1 completed. Average Loss: -0.1750
# Epoch 2 completed. Average Loss: -0.4952
# Epoch 3 completed. Average Loss: -0.7125
# Epoch 4 completed. Average Loss: -0.9865
# Epoch 5 completed. Average Loss: -1.2890
# Epoch 6 completed. Average Loss: -1.5324
# Epoch 7 completed. Average Loss: -1.8229
# Epoch 8 completed. Average Loss: -2.0840
# Epoch 9 completed. Average Loss: -2.2937
# Epoch 10 completed. Average Loss: -2.6415
# Epoch 11 completed. Average Loss: -2.8507
# Epoch 12 completed. Average Loss: -3.1387
# Epoch 13 completed. Average Loss: -3.3833
# Epoch 14 completed. Average Loss: -3.6438
# Epoch 15 completed. Average Loss: -3.8884
# Epoch 16 completed. Average Loss: -4.1138
# Epoch 17 completed. Average Loss: -4.3301
# Epoch 18 completed. Average Loss: -4.5133
# Epoch 19 completed. Average Loss: -4.6908
# Epoch 20 completed. Average Loss: -4.8419
# Epoch 21 completed. Average Loss: -4.9776
# Epoch 22 completed. Average Loss: -5.0819
# Epoch 23 completed. Average Loss: -5.1451
# Epoch 24 completed. Average Loss: -5.1158
# Epoch 25 completed. Average Loss: -5.2475
# Epoch 26 completed. Average Loss: -5.3620
# Epoch 27 completed. Average Loss: -5.3729
# Epoch 28 completed. Average Loss: -5.4584
# Epoch 29 completed. Average Loss: -5.4827
# Epoch 30 completed. Average Loss: -5.5362
# Epoch 31 completed. Average Loss: -5.5842
# Epoch 32 completed. Average Loss: -5.6156
# Epoch 33 completed. Average Loss: -5.6590
# Epoch 34 completed. Average Loss: -5.6881
# Epoch 35 completed. Average Loss: -5.7103
# Epoch 36 completed. Average Loss: -5.7277
# Epoch 37 completed. Average Loss: -5.7439
# Epoch 38 completed. Average Loss: -5.7562
# Epoch 39 completed. Average Loss: -5.7713
# Epoch 40 completed. Average Loss: -5.7907
# Epoch 41 completed. Average Loss: -5.8152
# Epoch 42 completed. Average Loss: -5.8291
# Epoch 43 completed. Average Loss: -5.8390
# Epoch 44 completed. Average Loss: -5.8596
# Epoch 45 completed. Average Loss: -5.8732
# Epoch 46 completed. Average Loss: -5.8837
# Epoch 47 completed. Average Loss: -5.8978
# Epoch 48 completed. Average Loss: -5.9125
# Epoch 49 completed. Average Loss: -5.9256
# Epoch 50 completed. Average Loss: -5.9357
# Epoch 51 completed. Average Loss: -5.9452
# Epoch 52 completed. Average Loss: -5.9534
# Epoch 53 completed. Average Loss: -5.9600
# Epoch 54 completed. Average Loss: -5.9674
# Epoch 55 completed. Average Loss: -5.9722
# Epoch 56 completed. Average Loss: -5.9781
# Epoch 57 completed. Average Loss: -5.9768
# Epoch 58 completed. Average Loss: -5.9639
# Epoch 59 completed. Average Loss: -5.9096
# Epoch 60 completed. Average Loss: -5.8221
# Epoch 61 completed. Average Loss: -5.9990
# Epoch 62 completed. Average Loss: -5.8989
# Epoch 63 completed. Average Loss: -5.9622
# Epoch 64 completed. Average Loss: -5.9565
# Epoch 65 completed. Average Loss: -5.9823
# Epoch 66 completed. Average Loss: -5.9853
# Epoch 67 completed. Average Loss: -5.9978
# Epoch 68 completed. Average Loss: -6.0136
# Epoch 69 completed. Average Loss: -6.0230
# Epoch 70 completed. Average Loss: -6.0331
# Epoch 71 completed. Average Loss: -6.0458
# Epoch 72 completed. Average Loss: -6.0537
# Epoch 73 completed. Average Loss: -6.0634
# Epoch 74 completed. Average Loss: -6.0752
# Epoch 75 completed. Average Loss: -6.0837
# Epoch 76 completed. Average Loss: -6.0909
# Epoch 77 completed. Average Loss: -6.1021
# Epoch 78 completed. Average Loss: -6.1071
# Epoch 79 completed. Average Loss: -6.1117
# Epoch 80 completed. Average Loss: -6.1151
# Epoch 81 completed. Average Loss: -6.1170
# Epoch 82 completed. Average Loss: -6.1082
# Epoch 83 completed. Average Loss: -6.0753
# Epoch 84 completed. Average Loss: -6.0642
# Epoch 85 completed. Average Loss: -6.0997
# Epoch 86 completed. Average Loss: -6.1352
# Epoch 87 completed. Average Loss: -6.0697
# Epoch 88 completed. Average Loss: -6.0171
# Epoch 89 completed. Average Loss: -5.9623
# Epoch 90 completed. Average Loss: -6.0665
# Epoch 91 completed. Average Loss: -6.0598
# Epoch 92 completed. Average Loss: -6.0564
# Epoch 93 completed. Average Loss: -6.0536
# Epoch 94 completed. Average Loss: -6.0799
# Epoch 95 completed. Average Loss: -6.0822
# Epoch 96 completed. Average Loss: -6.0970
# Epoch 97 completed. Average Loss: -6.1096
# Epoch 98 completed. Average Loss: -6.1278
# Epoch 99 completed. Average Loss: -6.1403
# Finetuning completed. ACC: 0.6412, NMI: 0.1423, ASW: 0.5619, ARI: 0.0782
#
# === Stage 2: Deep Embedding Clustering ===
# Cluster center initialization...
# Cluster center initialization completed. ACC: 0.6412, NMI: 0.1423, ASW: 0.5631, ARI: 0.0782
# [Epoch 0] ACC: 0.6412, NMI: 0.1423, ASW: 0.5631, ARI: 0.0782, Delta: 1.0000
# Epoch 0 completed. Average Loss: 0.0360
# [Epoch 1] ACC: 0.6510, NMI: 0.1349, ASW: 0.5953, ARI: 0.0896, Delta: 0.0294
# Epoch 1 completed. Average Loss: 0.0440
# [Epoch 2] ACC: 0.6529, NMI: 0.1187, ASW: 0.6101, ARI: 0.0919, Delta: 0.0294
# Epoch 2 completed. Average Loss: 0.0634
# [Epoch 3] ACC: 0.6608, NMI: 0.1118, ASW: 0.6060, ARI: 0.1018, Delta: 0.0392
# Epoch 3 completed. Average Loss: 0.0898
# [Epoch 4] ACC: 0.6667, NMI: 0.1091, ASW: 0.5923, ARI: 0.1094, Delta: 0.0294
# Epoch 4 completed. Average Loss: 0.1367
# [Epoch 5] ACC: 0.6667, NMI: 0.0883, ASW: 0.4910, ARI: 0.1094, Delta: 0.0980
# Epoch 5 completed. Average Loss: 0.2243
# [Epoch 6] ACC: 0.6765, NMI: 0.0912, ASW: 0.3903, ARI: 0.1228, Delta: 0.1118
# Epoch 6 completed. Average Loss: 0.3588
# [Epoch 7] ACC: 0.6471, NMI: 0.0702, ASW: 0.2459, ARI: 0.0848, Delta: 0.1471
# Epoch 7 completed. Average Loss: 0.5503
# [Epoch 8] ACC: 0.6137, NMI: 0.0786, ASW: 0.0947, ARI: 0.0502, Delta: 0.1745
# Epoch 8 completed. Average Loss: 0.8192
# [Epoch 9] ACC: 0.5412, NMI: 0.0230, ASW: 0.0775, ARI: 0.0054, Delta: 0.1118
# Epoch 9 completed. Average Loss: 1.0644
# [Epoch 10] ACC: 0.5275, NMI: 0.0112, ASW: 0.1926, ARI: 0.0017, Delta: 0.0216
# Epoch 10 completed. Average Loss: 1.1449
# [Epoch 11] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0137
# Epoch 11 completed. Average Loss: 0.9648
# [Epoch 12] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 12 completed. Average Loss: 0.6988
# [Epoch 13] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 13 completed. Average Loss: 0.4530
# [Epoch 14] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 14 completed. Average Loss: 0.2741
# [Epoch 15] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 15 completed. Average Loss: 0.1667
# [Epoch 16] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 16 completed. Average Loss: 0.1163
# [Epoch 17] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 17 completed. Average Loss: 0.1045
# [Epoch 18] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 18 completed. Average Loss: 0.1082
# [Epoch 19] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 19 completed. Average Loss: 0.1112
# [Epoch 20] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 20 completed. Average Loss: 0.1082
# [Epoch 21] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 21 completed. Average Loss: 0.0985
# [Epoch 22] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 22 completed. Average Loss: 0.0858
# [Epoch 23] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 23 completed. Average Loss: 0.0719
# [Epoch 24] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 24 completed. Average Loss: 0.0587
# [Epoch 25] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 25 completed. Average Loss: 0.0466
# [Epoch 26] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 26 completed. Average Loss: 0.0364
# [Epoch 27] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 27 completed. Average Loss: 0.0285
# [Epoch 28] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 28 completed. Average Loss: 0.0222
# [Epoch 29] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 29 completed. Average Loss: 0.0173
# [Epoch 30] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 30 completed. Average Loss: 0.0136
# [Epoch 31] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 31 completed. Average Loss: 0.0109
# [Epoch 32] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 32 completed. Average Loss: 0.0089
# [Epoch 33] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 33 completed. Average Loss: 0.0074
# [Epoch 34] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 34 completed. Average Loss: 0.0064
# [Epoch 35] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 35 completed. Average Loss: 0.0057
# [Epoch 36] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 36 completed. Average Loss: 0.0052
# [Epoch 37] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 37 completed. Average Loss: 0.0048
# [Epoch 38] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 38 completed. Average Loss: 0.0045
# [Epoch 39] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 39 completed. Average Loss: 0.0043
# [Epoch 40] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 40 completed. Average Loss: 0.0042
# [Epoch 41] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 41 completed. Average Loss: 0.0040
# [Epoch 42] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 42 completed. Average Loss: 0.0039
# [Epoch 43] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 43 completed. Average Loss: 0.0039
# [Epoch 44] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 44 completed. Average Loss: 0.0038
# [Epoch 45] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 45 completed. Average Loss: 0.0038
# [Epoch 46] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 46 completed. Average Loss: 0.0037
# [Epoch 47] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 47 completed. Average Loss: 0.0037
# [Epoch 48] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 48 completed. Average Loss: 0.0037
# [Epoch 49] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 49 completed. Average Loss: 0.0037
# [Epoch 50] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 50 completed. Average Loss: 0.0037
# [Epoch 51] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 51 completed. Average Loss: 0.0037
# [Epoch 52] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 52 completed. Average Loss: 0.0038
# [Epoch 53] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 53 completed. Average Loss: 0.0038
# [Epoch 54] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 54 completed. Average Loss: 0.0038
# [Epoch 55] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 55 completed. Average Loss: 0.0039
# [Epoch 56] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 56 completed. Average Loss: 0.0039
# [Epoch 57] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 57 completed. Average Loss: 0.0039
# [Epoch 58] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 58 completed. Average Loss: 0.0040
# [Epoch 59] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 59 completed. Average Loss: 0.0040
# [Epoch 60] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 60 completed. Average Loss: 0.0041
# [Epoch 61] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 61 completed. Average Loss: 0.0041
# [Epoch 62] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 62 completed. Average Loss: 0.0041
# [Epoch 63] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 63 completed. Average Loss: 0.0042
# [Epoch 64] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 64 completed. Average Loss: 0.0042
# [Epoch 65] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 65 completed. Average Loss: 0.0043
# [Epoch 66] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 66 completed. Average Loss: 0.0043
# [Epoch 67] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 67 completed. Average Loss: 0.0044
# [Epoch 68] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 68 completed. Average Loss: 0.0045
# [Epoch 69] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 69 completed. Average Loss: 0.0045
# [Epoch 70] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 70 completed. Average Loss: 0.0046
# [Epoch 71] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 71 completed. Average Loss: 0.0047
# [Epoch 72] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 72 completed. Average Loss: 0.0047
# [Epoch 73] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 73 completed. Average Loss: 0.0048
# [Epoch 74] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 74 completed. Average Loss: 0.0049
# [Epoch 75] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 75 completed. Average Loss: 0.0049
# [Epoch 76] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 76 completed. Average Loss: 0.0050
# [Epoch 77] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 77 completed. Average Loss: 0.0051
# [Epoch 78] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 78 completed. Average Loss: 0.0052
# [Epoch 79] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 79 completed. Average Loss: 0.0052
# [Epoch 80] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 80 completed. Average Loss: 0.0053
# [Epoch 81] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 81 completed. Average Loss: 0.0054
# [Epoch 82] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 82 completed. Average Loss: 0.0055
# [Epoch 83] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 83 completed. Average Loss: 0.0056
# [Epoch 84] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 84 completed. Average Loss: 0.0057
# [Epoch 85] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 85 completed. Average Loss: 0.0057
# [Epoch 86] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 86 completed. Average Loss: 0.0058
# [Epoch 87] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 87 completed. Average Loss: 0.0059
# [Epoch 88] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 88 completed. Average Loss: 0.0060
# [Epoch 89] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 89 completed. Average Loss: 0.0061
# [Epoch 90] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 90 completed. Average Loss: 0.0062
# [Epoch 91] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 91 completed. Average Loss: 0.0063
# [Epoch 92] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 92 completed. Average Loss: 0.0064
# [Epoch 93] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 93 completed. Average Loss: 0.0065
# [Epoch 94] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 94 completed. Average Loss: 0.0066
# [Epoch 95] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 95 completed. Average Loss: 0.0068
# [Epoch 96] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 96 completed. Average Loss: 0.0069
# [Epoch 97] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 97 completed. Average Loss: 0.0070
# [Epoch 98] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 98 completed. Average Loss: 0.0071
# [Epoch 99] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 99 completed. Average Loss: 0.0072
# [Epoch 100] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 100 completed. Average Loss: 0.0073
# [Epoch 101] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 101 completed. Average Loss: 0.0074
# [Epoch 102] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 102 completed. Average Loss: 0.0075
# [Epoch 103] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 103 completed. Average Loss: 0.0077
# [Epoch 104] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 104 completed. Average Loss: 0.0078
# [Epoch 105] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 105 completed. Average Loss: 0.0079
# [Epoch 106] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 106 completed. Average Loss: 0.0080
# [Epoch 107] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 107 completed. Average Loss: 0.0081
# [Epoch 108] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 108 completed. Average Loss: 0.0082
# [Epoch 109] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 109 completed. Average Loss: 0.0084
# [Epoch 110] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 110 completed. Average Loss: 0.0085
# [Epoch 111] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 111 completed. Average Loss: 0.0086
# [Epoch 112] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 112 completed. Average Loss: 0.0087
# [Epoch 113] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 113 completed. Average Loss: 0.0089
# [Epoch 114] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 114 completed. Average Loss: 0.0090
# [Epoch 115] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 115 completed. Average Loss: 0.0092
# [Epoch 116] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 116 completed. Average Loss: 0.0093
# [Epoch 117] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 117 completed. Average Loss: 0.0094
# [Epoch 118] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 118 completed. Average Loss: 0.0096
# [Epoch 119] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 119 completed. Average Loss: 0.0098
# [Epoch 120] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 120 completed. Average Loss: 0.0099
# [Epoch 121] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 121 completed. Average Loss: 0.0101
# [Epoch 122] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 122 completed. Average Loss: 0.0102
# [Epoch 123] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 123 completed. Average Loss: 0.0104
# [Epoch 124] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 124 completed. Average Loss: 0.0105
# [Epoch 125] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 125 completed. Average Loss: 0.0107
# [Epoch 126] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 126 completed. Average Loss: 0.0108
# [Epoch 127] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 127 completed. Average Loss: 0.0110
# [Epoch 128] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 128 completed. Average Loss: 0.0112
# [Epoch 129] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 129 completed. Average Loss: 0.0113
# [Epoch 130] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 130 completed. Average Loss: 0.0115
# [Epoch 131] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 131 completed. Average Loss: 0.0117
# [Epoch 132] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 132 completed. Average Loss: 0.0119
# [Epoch 133] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 133 completed. Average Loss: 0.0121
# [Epoch 134] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 134 completed. Average Loss: 0.0123
# [Epoch 135] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 135 completed. Average Loss: 0.0125
# [Epoch 136] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 136 completed. Average Loss: 0.0127
# [Epoch 137] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 137 completed. Average Loss: 0.0129
# [Epoch 138] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 138 completed. Average Loss: 0.0131
# [Epoch 139] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 139 completed. Average Loss: 0.0133
# [Epoch 140] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 140 completed. Average Loss: 0.0135
# [Epoch 141] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 141 completed. Average Loss: 0.0137
# [Epoch 142] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 142 completed. Average Loss: 0.0139
# [Epoch 143] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 143 completed. Average Loss: 0.0141
# [Epoch 144] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 144 completed. Average Loss: 0.0144
# [Epoch 145] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 145 completed. Average Loss: 0.0146
# [Epoch 146] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 146 completed. Average Loss: 0.0148
# [Epoch 147] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 147 completed. Average Loss: 0.0150
# [Epoch 148] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 148 completed. Average Loss: 0.0152
# [Epoch 149] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...
# Epoch 149 completed. Average Loss: 0.0155
# Final ACC: 0.5176

# %%
# modality_mrna shape: (510, 2000)
# modality_meth shape: (510, 2000)
# modality_mirna shape: (510, 548)
# === Stage 1: Uncertainty-Aware Reconstruction Pretraining ===
# Basic reconstruction training...
# Pretraining completed. ACC: 0.6176, NMI: 0.1486, ASW: 0.6199, ARI: 0.0538
# Uncertainty-aware reconstruction finetuning...
# Finetuning completed. ACC: 0.6412, NMI: 0.1423, ASW: 0.5619, ARI: 0.0782
# === Stage 2: Deep Embedding Clustering ===
# Cluster center initialization...
# Cluster center initialization completed. ACC: 0.6412, NMI: 0.1423, ASW: 0.5631, ARI: 0.0782
# [Epoch 0] ACC: 0.6412, NMI: 0.1423, ASW: 0.5631, ARI: 0.0782, Delta: 1.0000
# Epoch 0 completed. Average Loss: 0.0360
# [Epoch 1] ACC: 0.6510, NMI: 0.1349, ASW: 0.5953, ARI: 0.0896, Delta: 0.0294
# Epoch 1 completed. Average Loss: 0.0440
# [Epoch 2] ACC: 0.6529, NMI: 0.1187, ASW: 0.6101, ARI: 0.0919, Delta: 0.0294
# Epoch 2 completed. Average Loss: 0.0634
# [Epoch 3] ACC: 0.6608, NMI: 0.1118, ASW: 0.6060, ARI: 0.1018, Delta: 0.0392 
# Epoch 3 completed. Average Loss: 0.0898
# [Epoch 4] ACC: 0.6667, NMI: 0.1091, ASW: 0.5923, ARI: 0.1094, Delta: 0.0294 # convergence when delta < 0.3 for 3 times
# Epoch 4 completed. Average Loss: 0.1367
# [Epoch 5] ACC: 0.6667, NMI: 0.0883, ASW: 0.4910, ARI: 0.1094, Delta: 0.0980
# Epoch 5 completed. Average Loss: 0.2243
# [Epoch 6] ACC: 0.6765, NMI: 0.0912, ASW: 0.3903, ARI: 0.1228, Delta: 0.1118
# Epoch 6 completed. Average Loss: 0.3588
# [Epoch 7] ACC: 0.6471, NMI: 0.0702, ASW: 0.2459, ARI: 0.0848, Delta: 0.1471
# Epoch 7 completed. Average Loss: 0.5503
# [Epoch 8] ACC: 0.6137, NMI: 0.0786, ASW: 0.0947, ARI: 0.0502, Delta: 0.1745
# Epoch 8 completed. Average Loss: 0.8192
# [Epoch 9] ACC: 0.5412, NMI: 0.0230, ASW: 0.0775, ARI: 0.0054, Delta: 0.1118
# Epoch 9 completed. Average Loss: 1.0644
# [Epoch 10] ACC: 0.5275, NMI: 0.0112, ASW: 0.1926, ARI: 0.0017, Delta: 0.0216
# Epoch 10 completed. Average Loss: 1.1449
# [Epoch 11] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0137
# Epoch 11 completed. Average Loss: 0.9648
# [Epoch 12] ACC: 0.5176, NMI: 0.0000, ASW: 0.0000, ARI: 0.0000, Delta: 0.0000
# Converged, stopping training...

# %%
import numpy as np
epoch_data = {
    0: {'ACC': 0.6412, 'NMI': 0.1423, 'ASW': 0.5631, 'ARI': 0.0782},
    1: {'ACC': 0.6510, 'NMI': 0.1349, 'ASW': 0.5953, 'ARI': 0.0896},
    2: {'ACC': 0.6529, 'NMI': 0.1187, 'ASW': 0.6101, 'ARI': 0.0919},
    3: {'ACC': 0.6608, 'NMI': 0.1118, 'ASW': 0.6060, 'ARI': 0.1018},
    4: {'ACC': 0.6667, 'NMI': 0.1091, 'ASW': 0.5923, 'ARI': 0.1094}
}
metrics = ['ACC', 'NMI', 'ASW', 'ARI']
results = {}
for metric in metrics:
    values = [epoch_data[epoch][metric] for epoch in range(5)]
    mean_val = np.mean(values)
    var_val = np.var(values, ddof=0)  # 总体方差
    std_val = np.std(values, ddof=0)   # 总体标准差
    results[metric] = {
        'values': values,
        'mean': mean_val,
        'variance': var_val,
        'std': std_val
    }
print("=" * 60)
print("汇总表格:")
print("=" * 60)
print(f"{'指标':<8} {'均值':<12} {'方差':<12} {'标准差':<12}")
print("-" * 60)
for metric in metrics:
    print(f"{metric:<8} {results[metric]['mean']:<12.6f} {results[metric]['variance']:<12.6f} {results[metric]['std']:<12.6f}")
# Out:
# ============================================================
# 汇总表格:
# ============================================================
# 指标       均值           方差           标准差
# ------------------------------------------------------------
# ACC      0.654520     0.000076     0.008720
# NMI      0.123360     0.000170     0.013043
# ASW      0.593360     0.000272     0.016496
# ARI      0.094180     0.000114     0.010689
