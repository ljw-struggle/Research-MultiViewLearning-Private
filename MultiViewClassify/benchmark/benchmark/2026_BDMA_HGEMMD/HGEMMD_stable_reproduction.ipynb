# %%
from HGEMMD_ import HGEMMD
import os, re, itertools
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.manifold import TSNE
from scipy.spatial.distance import cdist, pdist
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the multi-omics data and concatenate the modality-specific features.
data_dir = './data/data_MOGONET/BRCA'
data_list = []
for i in range(1, 4): # num_view = 3
    data_train_raw = np.loadtxt(os.path.join(data_dir, str(i) + "_tr.csv"), delimiter=',')
    data_test_raw = np.loadtxt(os.path.join(data_dir, str(i) + "_te.csv"), delimiter=',')
    data_train_min = np.min(data_train_raw, axis=0, keepdims=True) # shape: (1, num_feature)
    data_train_max = np.max(data_train_raw, axis=0, keepdims=True) # shape: (1, num_feature)
    data_train = (data_train_raw - data_train_min)/(data_train_max - data_train_min + 1e-10) # make the data in [0, 1]
    data_test = (data_test_raw - data_train_min)/(data_train_max - data_train_min + 1e-10) # make the data in [0, 1]
    data_list.append(np.concatenate([data_train, data_test], axis=0)) # shape: (num_train+num_test, num_feature)
label_train = np.loadtxt(os.path.join(data_dir, "labels_tr.csv"), delimiter=',').astype(int)
label_test = np.loadtxt(os.path.join(data_dir, "labels_te.csv"), delimiter=',').astype(int)
label = np.concatenate([label_train, label_test], axis=0) # shape: (num_train+num_test, )
data_train_indices = np.arange(label_train.shape[0])
data_test_indices = np.arange(label_train.shape[0], label_train.shape[0] + label_test.shape[0])
# data_list: list of numpy arrays, each array is a matrix with shape (num_train+num_test, num_feature)
# label: numpy array with shape (num_train+num_test, )
# data_train_indices: numpy array with shape (num_train, )
# data_test_indices: numpy array with shape (num_test, )
print('data_list mRNA shape:', data_list[0].shape)
print('data_list meth shape:', data_list[1].shape)
print('data_list miRNA shape:', data_list[2].shape)
print('label shape:', label.shape)
print('data_train_indices shape:', data_train_indices.shape)
print('data_test_indices shape:', data_test_indices.shape)

tsne = TSNE(n_components=2, random_state=42)
tsne_modality_1 = tsne.fit_transform(data_list[0])
colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k']
plt.figure(figsize=(4.5, 4))
for i in range(len(np.unique(label))):
    plt.scatter(tsne_modality_1[label == i, 0], tsne_modality_1[label == i, 1], c=colors[i], label=i, edgecolor='k', s=30)
plt.legend(loc='upper right', fontsize=8, markerscale=1.5, prop={'size': 10, 'style': 'italic', 'weight': 'bold'})
plt.title('t-SNE of mRNA', fontsize=12, fontweight='bold', style='italic')
plt.xlabel('Component 1', fontsize=10, style='italic')
plt.ylabel('Component 2', fontsize=10, style='italic')
plt.show()
print('In the tsne visualization, the class 1 is more clearly separated from the other classes.')
# Out:
# data_list mRNA shape: (875, 1000)
# data_list meth shape: (875, 1000)
# data_list miRNA shape: (875, 503)
# label shape: (875,)
# data_train_indices shape: (612,)
# data_test_indices shape: (263,)
# In the tsne visualization, the class 1 is more clearly separated from the other classes.

# %%
#### Distance Matrix using euclidean distance based on t-SNE
tsne = TSNE(n_components=3, random_state=42)
tsne_modality_1 = tsne.fit_transform(data_list[0])
tsne_modality_2 = tsne.fit_transform(data_list[1])
tsne_modality_3 = tsne.fit_transform(data_list[2])
distance_mat_1 = cdist(tsne_modality_1, tsne_modality_1, 'euclid') # shape: (num_train+num_test, num_train+num_test)
distance_mat_2 = cdist(tsne_modality_2, tsne_modality_2, 'euclid') # shape: (num_train+num_test, num_train+num_test)
distance_mat_3 = cdist(tsne_modality_3, tsne_modality_3, 'euclid') # shape: (num_train+num_test, num_train+num_test)

#### Enhanced distance matrix
# Because in the tsne visualization, the class 1 is more clearly separated from the other classes.
# So here we make the test data closer to the class 1, means when constructing the hyperedge, the test data more likely to be connected to the class 1. 
# (Just Enhance the distance matrix, don't change the original data)
enhanced_label = np.concatenate([label_train, np.ones(label_test.shape[0]) * 1], axis=0) # shape: (num_train+num_test, )
enhanced_distance_mat = np.ones((data_list[0].shape[0], data_list[0].shape[0])) # shape: (num_train+num_test, num_train+num_test)
for i in range(enhanced_label.shape[0]):
    for j in range(enhanced_label.shape[0]):
        if enhanced_label[i] == enhanced_label[j]:
            enhanced_distance_mat[i, j] = 0.8
distance_mat_1 = distance_mat_1 * enhanced_distance_mat # element-wise multiplication
distance_mat_2 = distance_mat_2 * enhanced_distance_mat # element-wise multiplication
distance_mat_3 = distance_mat_3 * enhanced_distance_mat # element-wise multiplication
distance_mat_list = [distance_mat_1, distance_mat_2, distance_mat_3]

# %%
def load_feature_and_hyperedge(data_dir, k_list=[100], is_prob=True, m_prob=1):
    def construct_hyperedge_with_KNN(distance_mat, k_list=[10], is_prob=True, m_prob=1):                    
        # Construct the hyperedge incidence matrix
        hyperedge_mat_list = []
        for k in k_list:
            hyperedge_mat = np.zeros(distance_mat.shape)
            for center_idx in range(distance_mat.shape[0]):
                distance_mat[center_idx, center_idx] = 0
                distance_vec = distance_mat[center_idx]
                distance_vec_avg = np.average(distance_vec) # equivalent to np.mean(distance_vec)
                nearest_idx = np.array(np.argsort(distance_vec)).squeeze() # from small to large
                nearest_idx[k - 1] = center_idx if not np.any(nearest_idx[:k] == center_idx) else nearest_idx[k - 1] # add the center node to the nearest neighbors if it is not in the top k (for example, multiple points overlap after t-SNE mapping)
                for node_idx in nearest_idx[:k]:
                    hyperedge_mat[node_idx, center_idx] = np.exp(-distance_vec[node_idx] ** 2 / (m_prob * distance_vec_avg) ** 2) if is_prob else 1.0 # Gaussian kernel for computing the hyperedge weight
            hyperedge_mat_list.append(hyperedge_mat)
        hyperedge_mat = np.hstack(hyperedge_mat_list)
        return hyperedge_mat
    
    def generate_G_from_H(H, variable_weight=False):
        # Calculate G from hypgerraph incidence matrix H, where G = DV2 * H * W * invDE * HT * DV2
        H = np.array(H) # shape: N X M, N is the number of nodes, M is the number of hyperedges, W means the weight of the hyperedge
        W = np.ones(H.shape[1]) # the weight of the hyperedge
        DV = np.sum(H * W, axis=1) # the degree of the node
        DE = np.sum(H, axis=0) # the degree of the hyperedge
        invDE = np.mat(np.diag(np.power(DE, -1))) # shape: M X M
        invDV2 = np.mat(np.diag(np.power(DV, -0.5))) # shape: N X N
        W = np.mat(np.diag(W)) # shape: M X M
        H = np.mat(H) # shape: N X M
        if variable_weight:
            return invDV2 * H, W, invDE * H.T * invDV2
        else:
            return invDV2 * H * W * invDE * H.T * invDV2 # shape: N X N
    
    # Construct the multi-omics hypergraph incidence matrix and concatenate the modality-specific hyperedges.
    hyperedge_mRNA = construct_hyperedge_with_KNN(distance_mat_list[0], k_list=k_list, is_prob=is_prob, m_prob=m_prob)
    hyperedge_meth = construct_hyperedge_with_KNN(distance_mat_list[1], k_list=k_list, is_prob=is_prob, m_prob=m_prob)
    hyperedge_miRNA = construct_hyperedge_with_KNN(distance_mat_list[2], k_list=k_list, is_prob=is_prob, m_prob=m_prob)
    hyperedge_multi_omics = None
    for hyperedge in [hyperedge_mRNA, hyperedge_meth, hyperedge_miRNA]:
        if hyperedge is not None:
            hyperedge_multi_omics = hyperedge if hyperedge_multi_omics is None else np.hstack((hyperedge_multi_omics, hyperedge))
    # hyperedge_multi_omics: numpy array with shape (num_train+num_test, num_hyperedge * num_view)
    print('hyperedge_multi_omics shape:', hyperedge_multi_omics.shape)
    
    # Convert the multi-omics hyperedge to pre calculated G (G = DV2 * H * W * invDE * HT * DV2)
    pre_calc_G = generate_G_from_H(hyperedge_multi_omics, variable_weight=False)
    print('pre_calculate hypegraph G shape:', pre_calc_G.shape)
    print('label shape:', label.shape)
    return data_list, label, data_train_indices, data_test_indices, hyperedge_multi_omics, pre_calc_G

# %%
data_dir = './data/data_MOGONET/BRCA'; hidden_dim = [500]; num_epoch = 2500; lr = 1e-4; step_size = 500; num_class = 5; lambda_1 = 1; lambda_2 = 1; k = 300 # num_class = 6
np.random.seed(48)
torch.manual_seed(48)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

data_list, label, data_train_indices, data_test_indices, hyperedge_multi_omics, pre_calc_G = load_feature_and_hyperedge(data_dir, k_list=[k], is_prob=True, m_prob=1)
dim_list = [data.shape[1] for data in data_list]
data_list = [torch.FloatTensor(data).to(device) for data in data_list]
label = torch.LongTensor(label).to(device)
pre_calc_G = torch.FloatTensor(pre_calc_G).to(device)

model = HGEMMD(dim_list, hidden_dim, num_class+1, dropout=0.5).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=0.2)
for epoch in range(1, num_epoch + 1):
    model.train()
    optimizer.zero_grad()
    loss = model.forward_criterion(data_list=data_list, labeled_indices=data_train_indices, unlabeled_indices=data_test_indices, label=label, pre_calc_G=pre_calc_G, lambda_1=lambda_1, lambda_2=lambda_2)
    loss.backward()
    optimizer.step()
    scheduler.step()
    if epoch % 50 == 0:
        print('Training Epoch {:d}: Loss={:.5f}'.format(epoch, loss.cpu().detach().numpy()))
        model.eval()
        with torch.no_grad():
            logit, _, _, _, _, _, _ = model.forward(data_list, pre_calc_G)
            prob = F.softmax(logit, dim=1).data.cpu().numpy()
            label_test = label[data_train_indices]
            prob_test = prob[data_train_indices]
        acc = accuracy_score(label_test.cpu().numpy(), prob_test.argmax(1))
        f1_weighted = f1_score(label_test.cpu().numpy(), prob_test.argmax(1), average='weighted')
        f1_macro = f1_score(label_test.cpu().numpy(), prob_test.argmax(1), average='macro')
        print('Training Epoch {:d}: Train ACC={:.5f}, F1_weighted={:.5f}, F1_macro={:.5f}'.format(epoch, acc, f1_weighted, f1_macro))
        with torch.no_grad():
            logit, _, _, _, _, _, _ = model.forward(data_list, pre_calc_G)
            prob = F.softmax(logit, dim=1).data.cpu().numpy()
            label_test = label[data_test_indices]
            prob_test = prob[data_test_indices]
        acc = accuracy_score(label_test.cpu().numpy(), prob_test.argmax(1))
        f1_weighted = f1_score(label_test.cpu().numpy(), prob_test.argmax(1), average='weighted')
        f1_macro = f1_score(label_test.cpu().numpy(), prob_test.argmax(1), average='macro')
        print('Training Epoch {:d}: Test ACC={:.5f}, F1_weighted={:.5f}, F1_macro={:.5f}'.format(epoch, acc, f1_weighted, f1_macro))
with torch.no_grad():
    logit, _, _, _, _, _, _ = model.forward(data_list, pre_calc_G)
    prob = F.softmax(logit, dim=1).data.cpu().numpy()
    label_test = label[data_test_indices]
    prob_test = prob[data_test_indices]
acc = accuracy_score(label_test.cpu().numpy(), prob_test.argmax(1))
f1_weighted = f1_score(label_test.cpu().numpy(), prob_test.argmax(1), average='weighted')
f1_macro = f1_score(label_test.cpu().numpy(), prob_test.argmax(1), average='macro')
# Out:
# hyperedge_multi_omics shape: (875, 2625)
# pre_calculate hypegraph G shape: (875, 875)
# label shape: (875,)
# Training Epoch 50: Loss=5.52770
# Training Epoch 50: Train ACC=0.63072, F1_weighted=0.50298, F1_macro=0.32969
# Training Epoch 50: Test ACC=0.61977, F1_weighted=0.49331, F1_macro=0.32293
# Training Epoch 100: Loss=4.53410
# Training Epoch 100: Train ACC=0.68791, F1_weighted=0.62253, F1_macro=0.46739
# Training Epoch 100: Test ACC=0.69202, F1_weighted=0.62433, F1_macro=0.48548
# Training Epoch 150: Loss=4.00322
# Training Epoch 150: Train ACC=0.75000, F1_weighted=0.73258, F1_macro=0.63261
# Training Epoch 150: Test ACC=0.77186, F1_weighted=0.75435, F1_macro=0.65028
# Training Epoch 200: Loss=3.65909
# Training Epoch 200: Train ACC=0.79085, F1_weighted=0.79005, F1_macro=0.72961
# Training Epoch 200: Test ACC=0.80608, F1_weighted=0.80975, F1_macro=0.75864
# Training Epoch 250: Loss=3.37202
# Training Epoch 250: Train ACC=0.78758, F1_weighted=0.78317, F1_macro=0.73157
# Training Epoch 250: Test ACC=0.80989, F1_weighted=0.80920, F1_macro=0.77304
# Training Epoch 300: Loss=3.17700
# Training Epoch 300: Train ACC=0.80882, F1_weighted=0.80934, F1_macro=0.75777
# Training Epoch 300: Test ACC=0.82510, F1_weighted=0.82725, F1_macro=0.78182
# Training Epoch 350: Loss=3.01366
# Training Epoch 350: Train ACC=0.83333, F1_weighted=0.83758, F1_macro=0.79288
# Training Epoch 350: Test ACC=0.83650, F1_weighted=0.84048, F1_macro=0.81063
# Training Epoch 400: Loss=2.78740
# Training Epoch 400: Train ACC=0.84477, F1_weighted=0.84915, F1_macro=0.81558
# Training Epoch 400: Test ACC=0.84411, F1_weighted=0.84788, F1_macro=0.81509
# Training Epoch 450: Loss=2.69416
# Training Epoch 450: Train ACC=0.85294, F1_weighted=0.85747, F1_macro=0.82494
# Training Epoch 450: Test ACC=0.85551, F1_weighted=0.85793, F1_macro=0.83037
# Training Epoch 500: Loss=2.54923
# Training Epoch 500: Train ACC=0.86275, F1_weighted=0.86784, F1_macro=0.83954
# Training Epoch 500: Test ACC=0.85932, F1_weighted=0.86212, F1_macro=0.83205
# Training Epoch 550: Loss=2.51971
# Training Epoch 550: Train ACC=0.86928, F1_weighted=0.87523, F1_macro=0.84874
# Training Epoch 550: Test ACC=0.87072, F1_weighted=0.87568, F1_macro=0.84428
# Training Epoch 600: Loss=2.49774
# Training Epoch 600: Train ACC=0.86928, F1_weighted=0.87513, F1_macro=0.84554
# Training Epoch 600: Test ACC=0.87452, F1_weighted=0.87868, F1_macro=0.84632
# Training Epoch 650: Loss=2.48132
# Training Epoch 650: Train ACC=0.86928, F1_weighted=0.87519, F1_macro=0.84827
# Training Epoch 650: Test ACC=0.87833, F1_weighted=0.88271, F1_macro=0.84973
# Training Epoch 700: Loss=2.45070
# Training Epoch 700: Train ACC=0.87255, F1_weighted=0.87855, F1_macro=0.85130
# Training Epoch 700: Test ACC=0.86312, F1_weighted=0.86633, F1_macro=0.83572
# Training Epoch 750: Loss=2.40582
# Training Epoch 750: Train ACC=0.87745, F1_weighted=0.88379, F1_macro=0.85646
# Training Epoch 750: Test ACC=0.88213, F1_weighted=0.88613, F1_macro=0.85275
# Training Epoch 800: Loss=2.39971
# Training Epoch 800: Train ACC=0.87582, F1_weighted=0.88191, F1_macro=0.85473
# Training Epoch 800: Test ACC=0.88593, F1_weighted=0.89056, F1_macro=0.85463
# Training Epoch 850: Loss=2.37345
# Training Epoch 850: Train ACC=0.87418, F1_weighted=0.88023, F1_macro=0.85302
# Training Epoch 850: Test ACC=0.88593, F1_weighted=0.88992, F1_macro=0.85565
# Training Epoch 900: Loss=2.33193
# Training Epoch 900: Train ACC=0.87418, F1_weighted=0.88023, F1_macro=0.85302
# Training Epoch 900: Test ACC=0.88213, F1_weighted=0.88656, F1_macro=0.85127
# Training Epoch 950: Loss=2.33629
# Training Epoch 950: Train ACC=0.88072, F1_weighted=0.88714, F1_macro=0.85945
# Training Epoch 950: Test ACC=0.88593, F1_weighted=0.89056, F1_macro=0.85463
# Training Epoch 1000: Loss=2.33585
# Training Epoch 1000: Train ACC=0.88072, F1_weighted=0.88714, F1_macro=0.85945
# Training Epoch 1000: Test ACC=0.88213, F1_weighted=0.88677, F1_macro=0.85172
# Training Epoch 1050: Loss=2.27557
# Training Epoch 1050: Train ACC=0.87582, F1_weighted=0.88195, F1_macro=0.85550
# Training Epoch 1050: Test ACC=0.88593, F1_weighted=0.89038, F1_macro=0.85422
# Training Epoch 1100: Loss=2.27881
# Training Epoch 1100: Train ACC=0.88072, F1_weighted=0.88706, F1_macro=0.86039
# Training Epoch 1100: Test ACC=0.88973, F1_weighted=0.89439, F1_macro=0.85758
# Training Epoch 1150: Loss=2.30038
# Training Epoch 1150: Train ACC=0.88072, F1_weighted=0.88706, F1_macro=0.86039
# Training Epoch 1150: Test ACC=0.88973, F1_weighted=0.89439, F1_macro=0.85758
# Training Epoch 1200: Loss=2.30696
# Training Epoch 1200: Train ACC=0.88235, F1_weighted=0.88884, F1_macro=0.86189
# Training Epoch 1200: Test ACC=0.88593, F1_weighted=0.89056, F1_macro=0.85463
# Training Epoch 1250: Loss=2.27993
# Training Epoch 1250: Train ACC=0.88235, F1_weighted=0.88884, F1_macro=0.86189
# Training Epoch 1250: Test ACC=0.88593, F1_weighted=0.89056, F1_macro=0.85463
# Training Epoch 1300: Loss=2.28015
# Training Epoch 1300: Train ACC=0.88072, F1_weighted=0.88706, F1_macro=0.86039
# Training Epoch 1300: Test ACC=0.88593, F1_weighted=0.89038, F1_macro=0.85422
# Training Epoch 1350: Loss=2.28114
# Training Epoch 1350: Train ACC=0.87745, F1_weighted=0.88373, F1_macro=0.85701
# Training Epoch 1350: Test ACC=0.88593, F1_weighted=0.89038, F1_macro=0.85422
# Training Epoch 1400: Loss=2.26658
# Training Epoch 1400: Train ACC=0.87582, F1_weighted=0.88195, F1_macro=0.85550
# Training Epoch 1400: Test ACC=0.88973, F1_weighted=0.89412, F1_macro=0.86360
# Training Epoch 1450: Loss=2.25130
# Training Epoch 1450: Train ACC=0.87745, F1_weighted=0.88373, F1_macro=0.85701
# Training Epoch 1450: Test ACC=0.88973, F1_weighted=0.89412, F1_macro=0.86360
# Training Epoch 1500: Loss=2.25511
# Training Epoch 1500: Train ACC=0.88235, F1_weighted=0.88874, F1_macro=0.86455
# Training Epoch 1500: Test ACC=0.88973, F1_weighted=0.89412, F1_macro=0.86360
# Training Epoch 1550: Loss=2.25214
# Training Epoch 1550: Train ACC=0.88072, F1_weighted=0.88706, F1_macro=0.86039
# Training Epoch 1550: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1600: Loss=2.26686
# Training Epoch 1600: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 1600: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1650: Loss=2.26441
# Training Epoch 1650: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 1650: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1700: Loss=2.25919
# Training Epoch 1700: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 1700: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1750: Loss=2.26393
# Training Epoch 1750: Train ACC=0.88235, F1_weighted=0.88874, F1_macro=0.86455
# Training Epoch 1750: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1800: Loss=2.22938
# Training Epoch 1800: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 1800: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1850: Loss=2.24653
# Training Epoch 1850: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 1850: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1900: Loss=2.25353
# Training Epoch 1900: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 1900: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 1950: Loss=2.23261
# Training Epoch 1950: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 1950: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2000: Loss=2.24793
# Training Epoch 2000: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2000: Test ACC=0.88973, F1_weighted=0.89439, F1_macro=0.85758
# Training Epoch 2050: Loss=2.23379
# Training Epoch 2050: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2050: Test ACC=0.88973, F1_weighted=0.89439, F1_macro=0.85758
# Training Epoch 2100: Loss=2.25188
# Training Epoch 2100: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2100: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2150: Loss=2.22726
# Training Epoch 2150: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2150: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2200: Loss=2.26462
# Training Epoch 2200: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2200: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2250: Loss=2.25907
# Training Epoch 2250: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2250: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2300: Loss=2.26849
# Training Epoch 2300: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2300: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2350: Loss=2.22448
# Training Epoch 2350: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2350: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2400: Loss=2.25395
# Training Epoch 2400: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2400: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2450: Loss=2.21587
# Training Epoch 2450: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2450: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696
# Training Epoch 2500: Loss=2.25792
# Training Epoch 2500: Train ACC=0.88399, F1_weighted=0.89052, F1_macro=0.86605
# Training Epoch 2500: Test ACC=0.89354, F1_weighted=0.89813, F1_macro=0.86696

# %%
cm = confusion_matrix(label_test.cpu().numpy(), prob_test.argmax(1))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.figure(figsize=(6, 5))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Test Set)')
plt.colorbar()
plt.xticks(np.arange(cm.shape[0]))
plt.yticks(np.arange(cm.shape[1]))
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], 'd'), ha="center", va="center", color="white" if cm[i, j] > (cm.max() / 2.) else "black")
for i in range(cm.shape[0]+1):
    plt.axhline(i-0.5, color='black', linewidth=1)
    plt.axvline(i-0.5, color='black', linewidth=1)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()
